# %%
import sys
import os
import random
import numpy as np
import pandas as pd
from datetime import datetime
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model

# ---------------------------
# 1) Parse Command-Line Args
# ---------------------------
# Example call: python script.py 100 my_data.csv my_saved_model.h5 20 8
# 1) samplesize = 100
# 2) infilename = 'my_data.csv'
# 3) targetmodel = 'my_saved_model.h5'
# 4) targetweight = 20  (Not used here, but remains as a parameter)
# 5) middle = 8
samplesize = 10000
infilename = "output/NV_nomask_covid300_10000.csv"
targetweight = 98
modelpath = "saved_model/lstm_cl7_98_covid19_position_20250308235700"     # Instead of building, we'll load this saved model

# ---------------------------
# 2) Constants and Setup
# ---------------------------
nucleotide_to_int = {'a': 0, 'c': 1, 'g': 2, 't': 3}
int_to_nucleotide = {0: 'a', 1: 'c', 2: 'g', 3: 't'}

num_classes = 4
seq_length = 16
NV_Len = 32  # Number of numeric features

# ---------------------------
# 3) Read CSV Data
# ---------------------------
dfm = pd.read_csv(infilename)

# Filter or sample data as needed
df_build = dfm.sample(samplesize, random_state=2008).reset_index(drop=True).copy()

#mask_train = dfm['mask1']
mask_train = 8
# Extract numeric features (32 columns)
featurelist = [
    'n_a', 'n_c', 'n_t', 'n_g',
    'mu_a', 'mu_c', 'mu_t', 'mu_g',
    'moment_a_2', 'moment_c_2', 'moment_t_2', 'moment_g_2',
    'moment_a_3', 'moment_c_3', 'moment_t_3', 'moment_g_3',
    'moment_a_4', 'moment_c_4', 'moment_t_4', 'moment_g_4',
    'moment_a_5', 'moment_c_5', 'moment_t_5', 'moment_g_5',
    'moment_a_6', 'moment_c_6', 'moment_t_6', 'moment_g_6',
    'moment_a_7', 'moment_c_7', 'moment_t_7', 'moment_g_7'
]
features = df_build[featurelist].copy()

# Reshape for LSTM: (samples, timesteps=32, features_per_timestep=1)
X_input = features.values.reshape((features.shape[0], features.shape[1], 1))

# ---------------------------
# 4) Load Existing Model
# ---------------------------
# If your model has a custom loss or custom layers, you need custom_objects dict
# For example, if you need `mask_loss`, define it and pass: custom_objects={'custom_loss': mask_loss(...)}
def mask_loss(mask_train, weight):
    def custom_loss(y_true, y_pred):
        # same as original definition if needed
        cross_entropy_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
        return cross_entropy_loss  # For simplicity, or the full code from before
    return custom_loss

# Custom objects dictionary, only if your model needs it
custom_objects = {
    'custom_loss': mask_loss(mask_train, targetweight)
}

model = load_model(modelpath, custom_objects=custom_objects)

# ---------------------------
# 5) Predict
# ---------------------------
predictions = model.predict(X_input)  
# 'predictions' is shape (samplesize, seq_length, num_classes)

# Convert to integer-coded nucleotides
predicted_nucleotides = np.argmax(predictions, axis=-1)  
# Now shape: (samplesize, seq_length)

# ---------------------------
# 6) Convert Predictions Back to Nucleotides
# ---------------------------
predicted_sequences = [
    ''.join(int_to_nucleotide[nuc] for nuc in seq)
    for seq in predicted_nucleotides
]

# ---------------------------
# 7) Print or Save Results
# ---------------------------
for i, seq in enumerate(predicted_sequences):
    print(f"Sample {i} -> Predicted subsequence: {seq}")



df_results = pd.DataFrame({
    "id": df_build["id"],
    "Position": df_build["Position"],
    #"Maskpos_1": df_build["mask1"],
    #"Maskpos_2": df_build["mask2"],
    "Original_Sequence": df_build["Sequence"],
    "Predicted_Sequence": predicted_sequences
})
df_results["Overall_Accuracy"] = [
    sum(ori == pred for ori, pred in zip(original, predicted)) / len(original)
    for original, predicted in zip(df_results["Original_Sequence"], df_results["Predicted_Sequence"])
]
print(df_results.head(10))

output_file = "NV_nomask_2_COVID_prediction.csv"
df_results.to_csv("NV_nomask_2_COVID_prediction.csv")
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Sample 0 -> Predicted subsequence: aaattaaattggcaaa
# Sample 1 -> Predicted subsequence: gacattctctctctca
# Sample 2 -> Predicted subsequence: ttaactttaatctcac
# Sample 3 -> Predicted subsequence: aaattgtgggctcaat
# Sample 4 -> Predicted subsequence: atctgtgtggctgtca
# Sample 5 -> Predicted subsequence: tgcttgcactgatgac
# Sample 6 -> Predicted subsequence: cattgttaacactcca
# Sample 7 -> Predicted subsequence: actcaatttgcttttg
# Sample 8 -> Predicted subsequence: gttgttgaatgtctta
# Sample 9 -> Predicted subsequence: cggtagcacaccttgt
# Sample 10 -> Predicted subsequence: ctatccccatgtgatt
# Sample 11 -> Predicted subsequence: ttcttcacgacattgg
# Sample 12 -> Predicted subsequence: ctgggtaggtacatgt
# Sample 13 -> Predicted subsequence: attacagatgctgtag
# Sample 14 -> Predicted subsequence: ggctgcgttatagctt
# Sample 15 -> Predicted subsequence: attttggaggaataca
# Sample 16 -> Predicted subsequence: aatgatatcctttcac
# Sample 17 -> Predicted subsequence: cacttgcagatgctgg
# Sample 18 -> Predicted subsequence: cttagtagaagttgaa
# Sample 19 -> Predicted subsequence: gacatcaaggacctgc
# Sample 20 -> Predicted subsequence: tagattatgtaccact
# Sample 21 -> Predicted subsequence: cttaccttttaagttg
# Sample 22 -> Predicted subsequence: ttacattctaccatct
# Sample 23 -> Predicted subsequence: ctggaaccaccttgta
# Sample 24 -> Predicted subsequence: ctagttacactagcca
# Sample 25 -> Predicted subsequence: acgctactaatgttgt
# Sample 26 -> Predicted subsequence: ttaagtttgtatgtga
# Sample 27 -> Predicted subsequence: aaatacgtagtgctgc
# Sample 28 -> Predicted subsequence: acttaggcgacgagct
# Sample 29 -> Predicted subsequence: gttactttggcctctt
# Sample 30 -> Predicted subsequence: atcctgtggtaatttt
# Sample 31 -> Predicted subsequence: tcattcgtttcggaag
# Sample 32 -> Predicted subsequence: gctgttatggccagta
# Sample 33 -> Predicted subsequence: gtccaaattttgtatt
# Sample 34 -> Predicted subsequence: tttaggtgacatctct
# Sample 35 -> Predicted subsequence: ttaccctgacaaagtt
# Sample 36 -> Predicted subsequence: tggtgttacccgtgaa
# Sample 37 -> Predicted subsequence: gtatgtccgcaattta
# Sample 38 -> Predicted subsequence: tggctacatactactt
# Sample 39 -> Predicted subsequence: agatgttgtgtacaca
# Sample 40 -> Predicted subsequence: agttgatgacccgtgt
# Sample 41 -> Predicted subsequence: gattggctgcaatcat
# Sample 42 -> Predicted subsequence: ttacaaacattggccg
# Sample 43 -> Predicted subsequence: aatcgtgctacaactt
# Sample 44 -> Predicted subsequence: attataagaaagacaa
# Sample 45 -> Predicted subsequence: tgactaaagaaggtgc
# Sample 46 -> Predicted subsequence: aatgaaagatctcagt
# Sample 47 -> Predicted subsequence: ttgtgctaatgaccct
# Sample 48 -> Predicted subsequence: aaacttactgacaatg
# Sample 49 -> Predicted subsequence: ttaaatggttacactg
# Sample 50 -> Predicted subsequence: atcttacaaccagaac
# Sample 51 -> Predicted subsequence: tcacttacatttgtgg
# Sample 52 -> Predicted subsequence: ttcttgacattacacc
# Sample 53 -> Predicted subsequence: taatccgtatgtttgc
# Sample 54 -> Predicted subsequence: aatgatgtttgtcaaa
# Sample 55 -> Predicted subsequence: tataggtccagacatg
# Sample 56 -> Predicted subsequence: tttgtccgaacaactg
# Sample 57 -> Predicted subsequence: gttgttcagactattg
# Sample 58 -> Predicted subsequence: ggaacaaatacttcta
# Sample 59 -> Predicted subsequence: ctttgtctctgatgca
# Sample 60 -> Predicted subsequence: tgattattacagatct
# Sample 61 -> Predicted subsequence: agagaagtgggttttg
# Sample 62 -> Predicted subsequence: ggaaaagcacactttc
# Sample 63 -> Predicted subsequence: gaaggccgctataaca
# Sample 64 -> Predicted subsequence: gccatggcagattcca
# Sample 65 -> Predicted subsequence: acactttgcttcacac
# Sample 66 -> Predicted subsequence: ttgcagatgctggctt
# Sample 67 -> Predicted subsequence: gttagagaaacaatga
# Sample 68 -> Predicted subsequence: tccatcatatgcagct
# Sample 69 -> Predicted subsequence: agccaatatggatcaa
# Sample 70 -> Predicted subsequence: cacttatgattgaacg
# Sample 71 -> Predicted subsequence: catgccgctgttgatg
# Sample 72 -> Predicted subsequence: caaccgctactttaga
# Sample 73 -> Predicted subsequence: tactgtactggttaca
# Sample 74 -> Predicted subsequence: tcactgagactcattg
# Sample 75 -> Predicted subsequence: atagagcaacaagagt
# Sample 76 -> Predicted subsequence: caggtgttcttactga
# Sample 77 -> Predicted subsequence: agtgctcaaaggagtc
# Sample 78 -> Predicted subsequence: gacaaattcccagttc
# Sample 79 -> Predicted subsequence: ctgtgcttttgctgta
# Sample 80 -> Predicted subsequence: tgctgcagtcataaca
# Sample 81 -> Predicted subsequence: cagatgtgactcaact
# Sample 82 -> Predicted subsequence: aatcagcaactgtgtt
# Sample 83 -> Predicted subsequence: cgcattcaaccaggac
# Sample 84 -> Predicted subsequence: tgtagaattgtttgaa
# Sample 85 -> Predicted subsequence: aaacgcaagcttcgat
# Sample 86 -> Predicted subsequence: ctattgtttggcatgt
# Sample 87 -> Predicted subsequence: aaatctgaattcttct
# Sample 88 -> Predicted subsequence: tgaagttgcgagagac
# Sample 89 -> Predicted subsequence: gagtttttagtgcagt
# Sample 90 -> Predicted subsequence: tctgaagaagtagtgg
# Sample 91 -> Predicted subsequence: atttttgtggaaaggg
# Sample 92 -> Predicted subsequence: cactagttgcaactgc
# Sample 93 -> Predicted subsequence: aagctgcttgttgtca
# Sample 94 -> Predicted subsequence: attacagaagaggttg
# Sample 95 -> Predicted subsequence: acaagtattttagtgg
# Sample 96 -> Predicted subsequence: agtcttgaaattccac
# Sample 97 -> Predicted subsequence: tttttgttaccttctc
# Sample 98 -> Predicted subsequence: gatttgccaataggta
# Sample 99 -> Predicted subsequence: ctactttagactgact
# Sample 100 -> Predicted subsequence: ctacaacttcctcaag
# Sample 101 -> Predicted subsequence: ttgttaatggtgttag
# Sample 102 -> Predicted subsequence: agtgttatggagtgtc
# Sample 103 -> Predicted subsequence: ctaatgacaaagcttg
# Sample 104 -> Predicted subsequence: atggtgttgtttgtac
# Sample 105 -> Predicted subsequence: cttattatcttttggt
# Sample 106 -> Predicted subsequence: gattggttagatgatg
# Sample 107 -> Predicted subsequence: ggttgttactcacaat
# Sample 108 -> Predicted subsequence: accacttcagagagct
# Sample 109 -> Predicted subsequence: atttgcccccagcgct
# Sample 110 -> Predicted subsequence: gttaattgtgatacat
# Sample 111 -> Predicted subsequence: tgcacttttatctact
# Sample 112 -> Predicted subsequence: gtctttgtttcaaatg
# Sample 113 -> Predicted subsequence: aaatcagctggttttc
# Sample 114 -> Predicted subsequence: tacgccctgacacacg
# Sample 115 -> Predicted subsequence: gctatgcacgctgctt
# Sample 116 -> Predicted subsequence: attccattgtttgtag
# Sample 117 -> Predicted subsequence: atgactctaaagaggg
# Sample 118 -> Predicted subsequence: tgcgctgtgcaccttt
# Sample 119 -> Predicted subsequence: tctgttgcttatgaaa
# Sample 120 -> Predicted subsequence: ttcttatgttggttgc
# Sample 121 -> Predicted subsequence: tattacagttaatgtt
# Sample 122 -> Predicted subsequence: ctctaataactctatt
# Sample 123 -> Predicted subsequence: cctgctagaatggctg
# Sample 124 -> Predicted subsequence: catgctatacatgtct
# Sample 125 -> Predicted subsequence: gattctgaagttgttc
# Sample 126 -> Predicted subsequence: gcttttgcaatgatgt
# Sample 127 -> Predicted subsequence: gccaactattttcttt
# Sample 128 -> Predicted subsequence: aactaaagccatagtt
# Sample 129 -> Predicted subsequence: tgtacagaaagtgtgt
# Sample 130 -> Predicted subsequence: ccgaataccataatga
# Sample 131 -> Predicted subsequence: ctctcatgaagtgtga
# Sample 132 -> Predicted subsequence: taactcaggttctgat
# Sample 133 -> Predicted subsequence: atatttcaactgaaat
# Sample 134 -> Predicted subsequence: actgcttttggcttag
# Sample 135 -> Predicted subsequence: tcaaatgaatcttaag
# Sample 136 -> Predicted subsequence: gaagtttaaggaaggt
# Sample 137 -> Predicted subsequence: tttgtgggtttataca
# Sample 138 -> Predicted subsequence: gggaatctggagtaaa
# Sample 139 -> Predicted subsequence: tgatattgctgctaga
# Sample 140 -> Predicted subsequence: taatttacttaaggat
# Sample 141 -> Predicted subsequence: atcaggagatgccaca
# Sample 142 -> Predicted subsequence: atacatcaccagatgt
# Sample 143 -> Predicted subsequence: aaccaatttatgatga
# Sample 144 -> Predicted subsequence: cagggaccacctggta
# Sample 145 -> Predicted subsequence: gctgtagcctcaaaga
# Sample 146 -> Predicted subsequence: tttagtctacttcttg
# Sample 147 -> Predicted subsequence: agagtatcatgacgtt
# Sample 148 -> Predicted subsequence: caaagcttgtgttgaa
# Sample 149 -> Predicted subsequence: ttgttcttttttttgt
# Sample 150 -> Predicted subsequence: gcatcagctgtagtgt
# Sample 151 -> Predicted subsequence: ttggttggtacaccag
# Sample 152 -> Predicted subsequence: taagagaattccttac
# Sample 153 -> Predicted subsequence: agattctttagacacc
# Sample 154 -> Predicted subsequence: tgtcactattgcaacc
# Sample 155 -> Predicted subsequence: atggctgtagttgtga
# Sample 156 -> Predicted subsequence: gttctatgaagacttt
# Sample 157 -> Predicted subsequence: ccttaaattccataat
# Sample 158 -> Predicted subsequence: aagttacaaaaggaaa
# Sample 159 -> Predicted subsequence: aacaaaggctagctct
# Sample 160 -> Predicted subsequence: cagaatatttcaattc
# Sample 161 -> Predicted subsequence: tgtagcctcaaagatt
# Sample 162 -> Predicted subsequence: atgaaaattttaatca
# Sample 163 -> Predicted subsequence: gaaaattttaatcagc
# Sample 164 -> Predicted subsequence: cttatgaaagacattc
# Sample 165 -> Predicted subsequence: acaacaaaggctagct
# Sample 166 -> Predicted subsequence: tgaacagccctatgtg
# Sample 167 -> Predicted subsequence: cataactctcaaaaag
# Sample 168 -> Predicted subsequence: ctattaccgttgaaga
# Sample 169 -> Predicted subsequence: aaccaaatgtgccttt
# Sample 170 -> Predicted subsequence: aaaagtctactaattt
# Sample 171 -> Predicted subsequence: gcactctccaagggtg
# Sample 172 -> Predicted subsequence: gtgtttatgattactt
# Sample 173 -> Predicted subsequence: ctcttgtgcagaatga
# Sample 174 -> Predicted subsequence: ctcttatgttggttgc
# Sample 175 -> Predicted subsequence: ttgcagttaaaatgtt
# Sample 176 -> Predicted subsequence: gtagtactttcttttg
# Sample 177 -> Predicted subsequence: tgttagaggtacaaca
# Sample 178 -> Predicted subsequence: gtgttgttcagttgac
# Sample 179 -> Predicted subsequence: taaagattggtcctat
# Sample 180 -> Predicted subsequence: tataaagcattcaaac
# Sample 181 -> Predicted subsequence: tgtttgatgcttacgt
# Sample 182 -> Predicted subsequence: agtcttgtctgttaat
# Sample 183 -> Predicted subsequence: cataggatacaaggct
# Sample 184 -> Predicted subsequence: aacaaagatagcactt
# Sample 185 -> Predicted subsequence: caccatctaggacgct
# Sample 186 -> Predicted subsequence: cttttggtgaatacag
# Sample 187 -> Predicted subsequence: taaatgctgttacgac
# Sample 188 -> Predicted subsequence: tggtggtattgtagct
# Sample 189 -> Predicted subsequence: caactctggaagaaac
# Sample 190 -> Predicted subsequence: agatgacaatttaatt
# Sample 191 -> Predicted subsequence: agcccgtcttacaccg
# Sample 192 -> Predicted subsequence: aagagaagtgggtttt
# Sample 193 -> Predicted subsequence: tacacgtaaccctgct
# Sample 194 -> Predicted subsequence: agtacagacactggtg
# Sample 195 -> Predicted subsequence: gttaactggttataag
# Sample 196 -> Predicted subsequence: cacatgcagaagaaac
# Sample 197 -> Predicted subsequence: tgcaaaatggtatgaa
# Sample 198 -> Predicted subsequence: tgctcttgctttgctg
# Sample 199 -> Predicted subsequence: ctatacagaaatttca
# Sample 200 -> Predicted subsequence: agttggataatgatgc
# Sample 201 -> Predicted subsequence: tagacggttgtaattc
# Sample 202 -> Predicted subsequence: ggcatgttaacaatgc
# Sample 203 -> Predicted subsequence: cctaaatagaggtatg
# Sample 204 -> Predicted subsequence: atgtacgaccctaaga
# Sample 205 -> Predicted subsequence: aaaatatttgttgatg
# Sample 206 -> Predicted subsequence: tatcagggtgttaact
# Sample 207 -> Predicted subsequence: tgcttactctaataac
# Sample 208 -> Predicted subsequence: ttacaaattgggagct
# Sample 209 -> Predicted subsequence: tctctcagaaacaaag
# Sample 210 -> Predicted subsequence: aagttggaaaagatgg
# Sample 211 -> Predicted subsequence: agtgccagctacagtt
# Sample 212 -> Predicted subsequence: ggtgactttaaactta
# Sample 213 -> Predicted subsequence: aactaagggcacacta
# Sample 214 -> Predicted subsequence: cggcgggcacgtagtg
# Sample 215 -> Predicted subsequence: atttaatagtgctatt
# Sample 216 -> Predicted subsequence: agaatgaattctcgta
# Sample 217 -> Predicted subsequence: taagaggggtgtatac
# Sample 218 -> Predicted subsequence: agaccttctagcacgt
# Sample 219 -> Predicted subsequence: tgatgtttctttttta
# Sample 220 -> Predicted subsequence: gactccgtggaggagg
# Sample 221 -> Predicted subsequence: caatttaagaaaggtg
# Sample 222 -> Predicted subsequence: tagcttactacaacac
# Sample 223 -> Predicted subsequence: tgcaagttgaatctga
# Sample 224 -> Predicted subsequence: tctaaactgataaata
# Sample 225 -> Predicted subsequence: tctgtttcttcacctg
# Sample 226 -> Predicted subsequence: caaaatgcacaagctt
# Sample 227 -> Predicted subsequence: gtggatcctgctgcaa
# Sample 228 -> Predicted subsequence: aaattgataggttgat
# Sample 229 -> Predicted subsequence: caaacaagctagtctt
# Sample 230 -> Predicted subsequence: gccagcgtggtggtag
# Sample 231 -> Predicted subsequence: agacatgttcctcgga
# Sample 232 -> Predicted subsequence: aacaagatgataagaa
# Sample 233 -> Predicted subsequence: ctacaaaagagatgct
# Sample 234 -> Predicted subsequence: aagtttgcagacatat
# Sample 235 -> Predicted subsequence: ttacaacagtagacaa
# Sample 236 -> Predicted subsequence: tttcataacagatgcg
# Sample 237 -> Predicted subsequence: tcactcggctgcatgc
# Sample 238 -> Predicted subsequence: cctaatatgatggtaa
# Sample 239 -> Predicted subsequence: tagatgccttcaaact
# Sample 240 -> Predicted subsequence: acacactggtttgtaa
# Sample 241 -> Predicted subsequence: gacaatttaattgatt
# Sample 242 -> Predicted subsequence: aatcattactacagac
# Sample 243 -> Predicted subsequence: agtttttgatggtaaa
# Sample 244 -> Predicted subsequence: gaacttacaccagttg
# Sample 245 -> Predicted subsequence: tgcttgctgctgttta
# Sample 246 -> Predicted subsequence: gacggttgtaattcat
# Sample 247 -> Predicted subsequence: taccttttacaattaa
# Sample 248 -> Predicted subsequence: actcattgatgctatg
# Sample 249 -> Predicted subsequence: gtacaactattgttaa
# Sample 250 -> Predicted subsequence: tacagcgtaaatataa
# Sample 251 -> Predicted subsequence: attcacagggactact
# Sample 252 -> Predicted subsequence: catctacaataaaatt
# Sample 253 -> Predicted subsequence: aaacccttgctactca
# Sample 254 -> Predicted subsequence: ctgccgttgccacata
# Sample 255 -> Predicted subsequence: ggtgtcagtgttataa
# Sample 256 -> Predicted subsequence: atattgctgctagaga
# Sample 257 -> Predicted subsequence: ttctttagaaactata
# Sample 258 -> Predicted subsequence: aattttctcccgcact
# Sample 259 -> Predicted subsequence: gagtcaccttttgtta
# Sample 260 -> Predicted subsequence: ctactgcaacgatacc
# Sample 261 -> Predicted subsequence: aaaaccagtctctgaa
# Sample 262 -> Predicted subsequence: actaagaaatctgctg
# Sample 263 -> Predicted subsequence: accatatggaattacc
# Sample 264 -> Predicted subsequence: tggtgatagtgcggaa
# Sample 265 -> Predicted subsequence: ttcctcacagaaaact
# Sample 266 -> Predicted subsequence: atacagttgaactcgg
# Sample 267 -> Predicted subsequence: tatgatcctttgcaac
# Sample 268 -> Predicted subsequence: acgagggcaattcacc
# Sample 269 -> Predicted subsequence: taccatttaatgatgg
# Sample 270 -> Predicted subsequence: agagaattccttacac
# Sample 271 -> Predicted subsequence: acttcttgctgttttt
# Sample 272 -> Predicted subsequence: gctttagatcaagcca
# Sample 273 -> Predicted subsequence: catttgtcatgatgga
# Sample 274 -> Predicted subsequence: ccatccatctttactt
# Sample 275 -> Predicted subsequence: ggcatatattcttttc
# Sample 276 -> Predicted subsequence: ttaaggaattacttgt
# Sample 277 -> Predicted subsequence: ttgatgttcaacaatg
# Sample 278 -> Predicted subsequence: tttaaacgggtttgcg
# Sample 279 -> Predicted subsequence: cactccaacaaataga
# Sample 280 -> Predicted subsequence: gaaggctatgccttcg
# Sample 281 -> Predicted subsequence: cgtggctttggagact
# Sample 282 -> Predicted subsequence: gtgtgctgactctatc
# Sample 283 -> Predicted subsequence: atgtagaaacatttta
# Sample 284 -> Predicted subsequence: tctaaggttggtggta
# Sample 285 -> Predicted subsequence: gtgttgaagaagttac
# Sample 286 -> Predicted subsequence: attccaacggtactat
# Sample 287 -> Predicted subsequence: tgataacaaatttgca
# Sample 288 -> Predicted subsequence: ttgattacgtctataa
# Sample 289 -> Predicted subsequence: taggtgaaacatttgt
# Sample 290 -> Predicted subsequence: agttatacattttggt
# Sample 291 -> Predicted subsequence: gtatagattgtttagg
# Sample 292 -> Predicted subsequence: catcttatgtccttcc
# Sample 293 -> Predicted subsequence: cttggacaatcaaaaa
# Sample 294 -> Predicted subsequence: caaggtattgggaacc
# Sample 295 -> Predicted subsequence: atgtgttgacatacct
# Sample 296 -> Predicted subsequence: tagatgaagagcaacc
# Sample 297 -> Predicted subsequence: taaggtaatcactggg
# Sample 298 -> Predicted subsequence: cacacaaggcagatgg
# Sample 299 -> Predicted subsequence: aaaggtgaagacattc
# Sample 300 -> Predicted subsequence: tttaacaaagacttct
# Sample 301 -> Predicted subsequence: ctctcaatgacttcag
# Sample 302 -> Predicted subsequence: ctgtttatagtgatgt
# Sample 303 -> Predicted subsequence: gagtttgtgtagatac
# Sample 304 -> Predicted subsequence: actccgtggaggaggt
# Sample 305 -> Predicted subsequence: ttggctttgtgtgctg
# Sample 306 -> Predicted subsequence: tcaccaagaatgtagt
# Sample 307 -> Predicted subsequence: aaactttgcaaccagt
# Sample 308 -> Predicted subsequence: gcgtcacttatcaaca
# Sample 309 -> Predicted subsequence: acacacttaaaaatct
# Sample 310 -> Predicted subsequence: gtgacaatattgcttt
# Sample 311 -> Predicted subsequence: atgcctaacatgctta
# Sample 312 -> Predicted subsequence: tcaaccaaaatgcaca
# Sample 313 -> Predicted subsequence: accaagcaagaggtca
# Sample 314 -> Predicted subsequence: tagattctttagacac
# Sample 315 -> Predicted subsequence: ttgcacttttgaatat
# Sample 316 -> Predicted subsequence: gcatgtgacttatgtc
# Sample 317 -> Predicted subsequence: gcagatgctggcttca
# Sample 318 -> Predicted subsequence: aatggggaatgtccaa
# Sample 319 -> Predicted subsequence: aaagatggctgatcaa
# Sample 320 -> Predicted subsequence: gtgctggtaaagcttc
# Sample 321 -> Predicted subsequence: actattaagggttcat
# Sample 322 -> Predicted subsequence: ttgtccctggtttcaa
# Sample 323 -> Predicted subsequence: acaacctaaatagagg
# Sample 324 -> Predicted subsequence: tgcgcaggtagcaaaa
# Sample 325 -> Predicted subsequence: caggttcgcgacgtgc
# Sample 326 -> Predicted subsequence: tagaggcttcatttaa
# Sample 327 -> Predicted subsequence: tggctgcttatgtaga
# Sample 328 -> Predicted subsequence: aattttgtatttccct
# Sample 329 -> Predicted subsequence: tttgacatctacaatg
# Sample 330 -> Predicted subsequence: attgacgcatacaaaa
# Sample 331 -> Predicted subsequence: aacaaaggttactttt
# Sample 332 -> Predicted subsequence: ccaccagatttgcatc
# Sample 333 -> Predicted subsequence: gctgtgtctaagggtt
# Sample 334 -> Predicted subsequence: acctgaagaacatttt
# Sample 335 -> Predicted subsequence: aaatttgatgaagacg
# Sample 336 -> Predicted subsequence: acttgatgaaaggatt
# Sample 337 -> Predicted subsequence: ttgacaaagttgaggc
# Sample 338 -> Predicted subsequence: gtgccactacttgtgg
# Sample 339 -> Predicted subsequence: acacagaaaagtactg
# Sample 340 -> Predicted subsequence: ttagagtaggagctag
# Sample 341 -> Predicted subsequence: ataagggtgttatcac
# Sample 342 -> Predicted subsequence: taacaccagtttactc
# Sample 343 -> Predicted subsequence: actttattgacactaa
# Sample 344 -> Predicted subsequence: ctaatgtctatgcaga
# Sample 345 -> Predicted subsequence: cttgcacctaatatga
# Sample 346 -> Predicted subsequence: tagagtatcatgacgt
# Sample 347 -> Predicted subsequence: taagtgcacctacact
# Sample 348 -> Predicted subsequence: tagatgtagttaactt
# Sample 349 -> Predicted subsequence: tgaccttcaaaattat
# Sample 350 -> Predicted subsequence: tctatgcagattcatt
# Sample 351 -> Predicted subsequence: cacgtctatcagttac
# Sample 352 -> Predicted subsequence: ttaagaatcatacatc
# Sample 353 -> Predicted subsequence: ttctgataaaggagtt
# Sample 354 -> Predicted subsequence: tttgctgtagatgctg
# Sample 355 -> Predicted subsequence: tatgaccagttgctgt
# Sample 356 -> Predicted subsequence: aaagtctgtgaatttc
# Sample 357 -> Predicted subsequence: agttttagtggttatt
# Sample 358 -> Predicted subsequence: tgatggtcaagtagac
# Sample 359 -> Predicted subsequence: ctctatagaaatagag
# Sample 360 -> Predicted subsequence: cttaacggtctttggc
# Sample 361 -> Predicted subsequence: tgggacacttcgcatg
# Sample 362 -> Predicted subsequence: tactacaacacaacaa
# Sample 363 -> Predicted subsequence: acatgaagaaacaatt
# Sample 364 -> Predicted subsequence: catggctttgagttga
# Sample 365 -> Predicted subsequence: tctattgccataccca
# Sample 366 -> Predicted subsequence: acaaacgtaatagagc
# Sample 367 -> Predicted subsequence: ggtgatgttgttcaag
# Sample 368 -> Predicted subsequence: gagttgaagtttaatc
# Sample 369 -> Predicted subsequence: accctaacatgtttat
# Sample 370 -> Predicted subsequence: tagatgctgctaaagc
# Sample 371 -> Predicted subsequence: tatcacttttgaactt
# Sample 372 -> Predicted subsequence: catattgttatgatac
# Sample 373 -> Predicted subsequence: aaaggtttggattata
# Sample 374 -> Predicted subsequence: acactttcctcgtgaa
# Sample 375 -> Predicted subsequence: atggcttaaatttgga
# Sample 376 -> Predicted subsequence: caagagggtgtggttg
# Sample 377 -> Predicted subsequence: tggtgttgtttctatg
# Sample 378 -> Predicted subsequence: actttcattaattgac
# Sample 379 -> Predicted subsequence: gatgtctttcatttgt
# Sample 380 -> Predicted subsequence: ctttggctttgctgga
# Sample 381 -> Predicted subsequence: caattcaactgtatta
# Sample 382 -> Predicted subsequence: gtacatttacttgtgc
# Sample 383 -> Predicted subsequence: ttgtggctatgaagta
# Sample 384 -> Predicted subsequence: actggtaatacacttc
# Sample 385 -> Predicted subsequence: tagaacagtatgtctt
# Sample 386 -> Predicted subsequence: cccaccaacagagcct
# Sample 387 -> Predicted subsequence: cagaaactaacattct
# Sample 388 -> Predicted subsequence: catttgtaattagagg
# Sample 389 -> Predicted subsequence: atccacagacacttga
# Sample 390 -> Predicted subsequence: tacatactacttattt
# Sample 391 -> Predicted subsequence: cacccgcaatcctgct
# Sample 392 -> Predicted subsequence: atttcacagagcaacc
# Sample 393 -> Predicted subsequence: atctgtaggtcccaaa
# Sample 394 -> Predicted subsequence: tagatcaggcattagt
# Sample 395 -> Predicted subsequence: agtcagttctttatta
# Sample 396 -> Predicted subsequence: tgagtactaccacaca
# Sample 397 -> Predicted subsequence: aatcaagatctcaatg
# Sample 398 -> Predicted subsequence: ctatctttatgcttta
# Sample 399 -> Predicted subsequence: tcattcactgtactct
# Sample 400 -> Predicted subsequence: gcagaccacacaaggc
# Sample 401 -> Predicted subsequence: aatcctactgaccagt
# Sample 402 -> Predicted subsequence: cagatgtagaaactaa
# Sample 403 -> Predicted subsequence: acagactttttcagtg
# Sample 404 -> Predicted subsequence: agaattacatctttca
# Sample 405 -> Predicted subsequence: tcttacctagagtttt
# Sample 406 -> Predicted subsequence: aacgtaatagagcaac
# Sample 407 -> Predicted subsequence: agtaaatttcccctta
# Sample 408 -> Predicted subsequence: tcaaactgttgattca
# Sample 409 -> Predicted subsequence: ggtggtttacatctac
# Sample 410 -> Predicted subsequence: ctgtaataagacagta
# Sample 411 -> Predicted subsequence: cccaagaagtttttgc
# Sample 412 -> Predicted subsequence: gagcaaccaattgatc
# Sample 413 -> Predicted subsequence: aatcttgattacatca
# Sample 414 -> Predicted subsequence: ttacccacttactaaa
# Sample 415 -> Predicted subsequence: tatcaaagtagccact
# Sample 416 -> Predicted subsequence: ttgtacgatcaatttt
# Sample 417 -> Predicted subsequence: ttatcagctggtattt
# Sample 418 -> Predicted subsequence: tcgaagacccagtccc
# Sample 419 -> Predicted subsequence: tatagtgggtgatgtt
# Sample 420 -> Predicted subsequence: tcactattgcaaccta
# Sample 421 -> Predicted subsequence: gtgcctgccaattcaa
# Sample 422 -> Predicted subsequence: tcacttgttcttgctc
# Sample 423 -> Predicted subsequence: taaaaagttgaagaag
# Sample 424 -> Predicted subsequence: gctctcaatgacttca
# Sample 425 -> Predicted subsequence: caaacacgtgcaggct
# Sample 426 -> Predicted subsequence: aagagctaccagacga
# Sample 427 -> Predicted subsequence: gttttggaccactagt
# Sample 428 -> Predicted subsequence: acatggctttgagttg
# Sample 429 -> Predicted subsequence: cctaatttttctaaac
# Sample 430 -> Predicted subsequence: tgctggtattgttggt
# Sample 431 -> Predicted subsequence: cttccttacccagatc
# Sample 432 -> Predicted subsequence: aaacctattgtttggc
# Sample 433 -> Predicted subsequence: ggtgaaaatactcaat
# Sample 434 -> Predicted subsequence: aacaacaacaaggcca
# Sample 435 -> Predicted subsequence: tgtgtgcttcattaaa
# Sample 436 -> Predicted subsequence: acatctactgattgga
# Sample 437 -> Predicted subsequence: tactttagactgactc
# Sample 438 -> Predicted subsequence: gtgacacacttaaaaa
# Sample 439 -> Predicted subsequence: gaggtgttgcaggagc
# Sample 440 -> Predicted subsequence: aggtttacaaccatct
# Sample 441 -> Predicted subsequence: aacttcatggcagacg
# Sample 442 -> Predicted subsequence: cagcacatatatctac
# Sample 443 -> Predicted subsequence: ctgaagacatgcttaa
# Sample 444 -> Predicted subsequence: tgtatgaccagttgct
# Sample 445 -> Predicted subsequence: ataccatttgctatgc
# Sample 446 -> Predicted subsequence: aaaagaacttcacaac
# Sample 447 -> Predicted subsequence: catgcttaaccctaat
# Sample 448 -> Predicted subsequence: ggtgtagatgctgtaa
# Sample 449 -> Predicted subsequence: tcagacattctttaag
# Sample 450 -> Predicted subsequence: taacaacttttgattc
# Sample 451 -> Predicted subsequence: ggtattggagttacac
# Sample 452 -> Predicted subsequence: tatcttctgcaggctg
# Sample 453 -> Predicted subsequence: ttattttgcttccact
# Sample 454 -> Predicted subsequence: tgttcaacaatggggt
# Sample 455 -> Predicted subsequence: cctttgacaatcttaa
# Sample 456 -> Predicted subsequence: aactaatggttgtcat
# Sample 457 -> Predicted subsequence: ctgtcataaaaacttt
# Sample 458 -> Predicted subsequence: tcagcacctttaattg
# Sample 459 -> Predicted subsequence: cactcaacaacattat
# Sample 460 -> Predicted subsequence: gtgtagatgctgtaaa
# Sample 461 -> Predicted subsequence: ggtgaagtttttaacg
# Sample 462 -> Predicted subsequence: tgcagggtgctgtaga
# Sample 463 -> Predicted subsequence: ttgtgcaaactttaat
# Sample 464 -> Predicted subsequence: ttacattacacataaa
# Sample 465 -> Predicted subsequence: caaaccacgccaggta
# Sample 466 -> Predicted subsequence: aaagggaggtaggttt
# Sample 467 -> Predicted subsequence: ttcttcgtaagaacgg
# Sample 468 -> Predicted subsequence: actgttgctacatcac
# Sample 469 -> Predicted subsequence: tgctgctcttgctttg
# Sample 470 -> Predicted subsequence: ctcaatgacttcagta
# Sample 471 -> Predicted subsequence: ctgaagaagtagtgga
# Sample 472 -> Predicted subsequence: aagagtgtgttagagg
# Sample 473 -> Predicted subsequence: ttttgctatgggtatt
# Sample 474 -> Predicted subsequence: cagattctgccactct
# Sample 475 -> Predicted subsequence: gatacagccaatccta
# Sample 476 -> Predicted subsequence: gagcacaaaaccagtt
# Sample 477 -> Predicted subsequence: cacccaaattgtgtta
# Sample 478 -> Predicted subsequence: gtcagacaaatcgctc
# Sample 479 -> Predicted subsequence: ggacagcctttgttac
# Sample 480 -> Predicted subsequence: ttattttaaaatatat
# Sample 481 -> Predicted subsequence: cctgtggtaattttaa
# Sample 482 -> Predicted subsequence: tggtgcatcgtgttgt
# Sample 483 -> Predicted subsequence: gctttgcttgtacagt
# Sample 484 -> Predicted subsequence: aacgagaaaacacacg
# Sample 485 -> Predicted subsequence: tgttttaagacagtgg
# Sample 486 -> Predicted subsequence: cacactcaaaggcggt
# Sample 487 -> Predicted subsequence: ctgtccaagacatgtg
# Sample 488 -> Predicted subsequence: tttgcatcagaggctg
# Sample 489 -> Predicted subsequence: gagttaggtgatgtta
# Sample 490 -> Predicted subsequence: caattacctgaaactt
# Sample 491 -> Predicted subsequence: aaatgctggtgattac
# Sample 492 -> Predicted subsequence: atcatatgggttgcaa
# Sample 493 -> Predicted subsequence: taaagaaatcactgtt
# Sample 494 -> Predicted subsequence: aacactttgcttcaca
# Sample 495 -> Predicted subsequence: gtgactatggtgatgc
# Sample 496 -> Predicted subsequence: ttcaactgaaatctat
# Sample 497 -> Predicted subsequence: gacaatcagacaacta
# Sample 498 -> Predicted subsequence: tcttttaagaaaggag
# Sample 499 -> Predicted subsequence: caaattctagaattaa
# Sample 500 -> Predicted subsequence: accgcttctagaaagt
# Sample 501 -> Predicted subsequence: aagttgatggtgttga
# Sample 502 -> Predicted subsequence: aacacagaccattcca
# Sample 503 -> Predicted subsequence: ttgtatttccacaaag
# Sample 504 -> Predicted subsequence: cgcagtataattaata
# Sample 505 -> Predicted subsequence: tcattctattggattt
# Sample 506 -> Predicted subsequence: ttaattttagtagtgc
# Sample 507 -> Predicted subsequence: ataaacgaacttatgg
# Sample 508 -> Predicted subsequence: gtagttgatgacccgt
# Sample 509 -> Predicted subsequence: gtagaaacattttacc
# Sample 510 -> Predicted subsequence: ccaatatggatcaaga
# Sample 511 -> Predicted subsequence: gtaaaggccaacaaca
# Sample 512 -> Predicted subsequence: aacaatttgatactta
# Sample 513 -> Predicted subsequence: tcaaaacttatagagt
# Sample 514 -> Predicted subsequence: aatctgtgtggctgtc
# Sample 515 -> Predicted subsequence: ttcagttgcttactct
# Sample 516 -> Predicted subsequence: tagtggtagatgggta
# Sample 517 -> Predicted subsequence: tggaaagtgagttcag
# Sample 518 -> Predicted subsequence: tcttttcactaggttt
# Sample 519 -> Predicted subsequence: tggtgtttcctttagt
# Sample 520 -> Predicted subsequence: ttagaggtaatgaagt
# Sample 521 -> Predicted subsequence: ttttaaaagaaccttg
# Sample 522 -> Predicted subsequence: atgaagtcagacaaat
# Sample 523 -> Predicted subsequence: ctgagaatttgactaa
# Sample 524 -> Predicted subsequence: gaacgctttcttatta
# Sample 525 -> Predicted subsequence: tatctttctgtgcttt
# Sample 526 -> Predicted subsequence: tggcactgataacact
# Sample 527 -> Predicted subsequence: tatctactgatggtaa
# Sample 528 -> Predicted subsequence: ttgtattgcatagacg
# Sample 529 -> Predicted subsequence: tgctagttacactagc
# Sample 530 -> Predicted subsequence: ttcactatatgttaaa
# Sample 531 -> Predicted subsequence: actgtaggcacggcac
# Sample 532 -> Predicted subsequence: acaatccatgagcagt
# Sample 533 -> Predicted subsequence: ataacagaacattctt
# Sample 534 -> Predicted subsequence: ttgcaacttgctgttg
# Sample 535 -> Predicted subsequence: acttcacaactgctcc
# Sample 536 -> Predicted subsequence: gtctgatgttggtgat
# Sample 537 -> Predicted subsequence: aaacagggtaatttca
# Sample 538 -> Predicted subsequence: tgtggccctgatggct
# Sample 539 -> Predicted subsequence: ggcaactataaattaa
# Sample 540 -> Predicted subsequence: attaagtgggatttgt
# Sample 541 -> Predicted subsequence: cacaactgatcctagt
# Sample 542 -> Predicted subsequence: ttaaattgtcacatca
# Sample 543 -> Predicted subsequence: ggtgatgaactgaaga
# Sample 544 -> Predicted subsequence: acgaattcgtggtggt
# Sample 545 -> Predicted subsequence: actatttgtagttgaa
# Sample 546 -> Predicted subsequence: aacggtataaattaga
# Sample 547 -> Predicted subsequence: gtactgaagatgatta
# Sample 548 -> Predicted subsequence: tgttcttactgagtct
# Sample 549 -> Predicted subsequence: cacctatccttcttta
# Sample 550 -> Predicted subsequence: tgtcagcattaaatca
# Sample 551 -> Predicted subsequence: atattaccagatccat
# Sample 552 -> Predicted subsequence: gtcactataaacatat
# Sample 553 -> Predicted subsequence: ctgtactggttacaga
# Sample 554 -> Predicted subsequence: ggtgctagattttact
# Sample 555 -> Predicted subsequence: aaacgtaatagagcaa
# Sample 556 -> Predicted subsequence: agttacttgtttcaac
# Sample 557 -> Predicted subsequence: aatgctattagaaaag
# Sample 558 -> Predicted subsequence: tggctgtcactcggct
# Sample 559 -> Predicted subsequence: gtactacacaaactgc
# Sample 560 -> Predicted subsequence: ctatgactttgctgtg
# Sample 561 -> Predicted subsequence: taaaagtgtatattac
# Sample 562 -> Predicted subsequence: cttaaacatggaggag
# Sample 563 -> Predicted subsequence: actgcagagtcacatg
# Sample 564 -> Predicted subsequence: tgctacgtgtataaca
# Sample 565 -> Predicted subsequence: gcctcaacttgaacag
# Sample 566 -> Predicted subsequence: agcctttgaaaaaatg
# Sample 567 -> Predicted subsequence: caaattacattacaca
# Sample 568 -> Predicted subsequence: tggacaattattataa
# Sample 569 -> Predicted subsequence: actttgtattgcatag
# Sample 570 -> Predicted subsequence: agcatggcctcttatt
# Sample 571 -> Predicted subsequence: aacttgctgttgttgt
# Sample 572 -> Predicted subsequence: gagaaggcattaaaat
# Sample 573 -> Predicted subsequence: ataacacctgttcatg
# Sample 574 -> Predicted subsequence: gattttggtggtttta
# Sample 575 -> Predicted subsequence: gggtgtagaagctgtt
# Sample 576 -> Predicted subsequence: cttttcactatgctta
# Sample 577 -> Predicted subsequence: caaggtgaaatcaagg
# Sample 578 -> Predicted subsequence: tggcactgatccttat
# Sample 579 -> Predicted subsequence: tctctcagccttttct
# Sample 580 -> Predicted subsequence: ggcagagacattgctg
# Sample 581 -> Predicted subsequence: ttttaaaatgaattat
# Sample 582 -> Predicted subsequence: aaacatactgactttt
# Sample 583 -> Predicted subsequence: gtaatacacttcagtg
# Sample 584 -> Predicted subsequence: taaacctagaccacca
# Sample 585 -> Predicted subsequence: gttgcggcaatagtgt
# Sample 586 -> Predicted subsequence: cactagtaatcctacc
# Sample 587 -> Predicted subsequence: ggtacgctgcttgtcg
# Sample 588 -> Predicted subsequence: attttgctgaataagc
# Sample 589 -> Predicted subsequence: aatggaagttctatga
# Sample 590 -> Predicted subsequence: ccgggtgttgctatgc
# Sample 591 -> Predicted subsequence: cagaggaagttgtctt
# Sample 592 -> Predicted subsequence: tacgtagaccattctt
# Sample 593 -> Predicted subsequence: acaaagcttgcccatt
# Sample 594 -> Predicted subsequence: gagaattccttacacg
# Sample 595 -> Predicted subsequence: cagctttaagggccaa
# Sample 596 -> Predicted subsequence: tacaatagtgtaactt
# Sample 597 -> Predicted subsequence: tggtacaggctggtaa
# Sample 598 -> Predicted subsequence: ggcacttgtgaaagat
# Sample 599 -> Predicted subsequence: ggtttacaaccatctg
# Sample 600 -> Predicted subsequence: aaattgcttggtacac
# Sample 601 -> Predicted subsequence: gtgcttttgctgtaga
# Sample 602 -> Predicted subsequence: tgttttacaggttcgc
# Sample 603 -> Predicted subsequence: acacttatgcctgttg
# Sample 604 -> Predicted subsequence: ctaaagcatacaatgt
# Sample 605 -> Predicted subsequence: taagagtgtcggtaaa
# Sample 606 -> Predicted subsequence: tactgacttttcaagt
# Sample 607 -> Predicted subsequence: ctattagaaaagtgtg
# Sample 608 -> Predicted subsequence: tacaaatggccccgat
# Sample 609 -> Predicted subsequence: ttctgaagttgttctt
# Sample 610 -> Predicted subsequence: agttcctcacagaaaa
# Sample 611 -> Predicted subsequence: tttacgcatatttgcg
# Sample 612 -> Predicted subsequence: cgaagttgtaggagac
# Sample 613 -> Predicted subsequence: agacacctaagtataa
# Sample 614 -> Predicted subsequence: tggcacaacatgttaa
# Sample 615 -> Predicted subsequence: ctggcgatagttgtaa
# Sample 616 -> Predicted subsequence: cttcaatggggaatgt
# Sample 617 -> Predicted subsequence: attggacattctatgc
# Sample 618 -> Predicted subsequence: atttcatttatgcttt
# Sample 619 -> Predicted subsequence: aaggccaaactgtcac
# Sample 620 -> Predicted subsequence: ggaaaacttcaagatg
# Sample 621 -> Predicted subsequence: ctacttttcaacaaag
# Sample 622 -> Predicted subsequence: tgatgttgtaatagga
# Sample 623 -> Predicted subsequence: tgttggagaaggttcc
# Sample 624 -> Predicted subsequence: aaaattcaagactcac
# Sample 625 -> Predicted subsequence: aatgtgaaaactaccg
# Sample 626 -> Predicted subsequence: tggcaaaccacgcgaa
# Sample 627 -> Predicted subsequence: attagaagattttatt
# Sample 628 -> Predicted subsequence: gcgtcttggttcaccg
# Sample 629 -> Predicted subsequence: agaactcaattaccct
# Sample 630 -> Predicted subsequence: attggttgaagcagtt
# Sample 631 -> Predicted subsequence: gcttctggtaatctat
# Sample 632 -> Predicted subsequence: cgaacatgaaatttct
# Sample 633 -> Predicted subsequence: gtaataggtttcctat
# Sample 634 -> Predicted subsequence: aaatccaacaggttgt
# Sample 635 -> Predicted subsequence: gggtgctgtagacata
# Sample 636 -> Predicted subsequence: gaattagactcattca
# Sample 637 -> Predicted subsequence: acaagttaatggttta
# Sample 638 -> Predicted subsequence: gctttgggctaagcgc
# Sample 639 -> Predicted subsequence: caactgtcatgttttt
# Sample 640 -> Predicted subsequence: ataaatggggtaaggc
# Sample 641 -> Predicted subsequence: atttttggtgctgacc
# Sample 642 -> Predicted subsequence: cctggtttgcctggca
# Sample 643 -> Predicted subsequence: gcttgcccattgattg
# Sample 644 -> Predicted subsequence: caagttgaatctgatg
# Sample 645 -> Predicted subsequence: gaaatgctggtattgt
# Sample 646 -> Predicted subsequence: gattatttcaataaaa
# Sample 647 -> Predicted subsequence: acaaatgtctacttag
# Sample 648 -> Predicted subsequence: gataatatcaaatttg
# Sample 649 -> Predicted subsequence: cctcttgagtgcatta
# Sample 650 -> Predicted subsequence: tttgctgatgatttaa
# Sample 651 -> Predicted subsequence: agaatctattgttaga
# Sample 652 -> Predicted subsequence: attctctacagtgttc
# Sample 653 -> Predicted subsequence: cgttgtcctgctgaaa
# Sample 654 -> Predicted subsequence: taattgttgtcgcttc
# Sample 655 -> Predicted subsequence: gcgaagatctaaaact
# Sample 656 -> Predicted subsequence: ctgccacagtacgtct
# Sample 657 -> Predicted subsequence: taaagttacatttttc
# Sample 658 -> Predicted subsequence: gttaaagccacttgcg
# Sample 659 -> Predicted subsequence: aacatggaggaggtgt
# Sample 660 -> Predicted subsequence: cagactataacacata
# Sample 661 -> Predicted subsequence: tggaagtcacaccttc
# Sample 662 -> Predicted subsequence: taaaaacagtaaagta
# Sample 663 -> Predicted subsequence: tataaacaggctagat
# Sample 664 -> Predicted subsequence: gagttcagagtttatt
# Sample 665 -> Predicted subsequence: atgtagtttacagtca
# Sample 666 -> Predicted subsequence: atctactcaaccgctg
# Sample 667 -> Predicted subsequence: aattgttacgactatt
# Sample 668 -> Predicted subsequence: gtttgcagacatatgt
# Sample 669 -> Predicted subsequence: tattttctatttaata
# Sample 670 -> Predicted subsequence: tcgataattttaagtt
# Sample 671 -> Predicted subsequence: accaatgtactagaag
# Sample 672 -> Predicted subsequence: tctcgtgttaaaaatc
# Sample 673 -> Predicted subsequence: aaatacacaatggcag
# Sample 674 -> Predicted subsequence: ttactctccaattttt
# Sample 675 -> Predicted subsequence: ctttcatttgtactta
# Sample 676 -> Predicted subsequence: caaaagtattctacac
# Sample 677 -> Predicted subsequence: gtacagattgtatctc
# Sample 678 -> Predicted subsequence: ggttcttcttcgtaag
# Sample 679 -> Predicted subsequence: aaggtccttttatgtc
# Sample 680 -> Predicted subsequence: ttgtacataatcagga
# Sample 681 -> Predicted subsequence: taattaaagttacact
# Sample 682 -> Predicted subsequence: aaattctaccagtgtc
# Sample 683 -> Predicted subsequence: aaaatgtgaagaatca
# Sample 684 -> Predicted subsequence: tacttcttcttctaaa
# Sample 685 -> Predicted subsequence: cgtctatcttctgcag
# Sample 686 -> Predicted subsequence: gctttacttacaaagt
# Sample 687 -> Predicted subsequence: taaatcaaaatgtgaa
# Sample 688 -> Predicted subsequence: gaacaaacccaaggaa
# Sample 689 -> Predicted subsequence: aaatcacataaaccac
# Sample 690 -> Predicted subsequence: tgccaacagacaatta
# Sample 691 -> Predicted subsequence: ttttgggactaccaac
# Sample 692 -> Predicted subsequence: aacatgtgactggaca
# Sample 693 -> Predicted subsequence: cttgaatacaccaaaa
# Sample 694 -> Predicted subsequence: accccctgcatacact
# Sample 695 -> Predicted subsequence: caagaaggagttagat
# Sample 696 -> Predicted subsequence: gtagctatcgtagtaa
# Sample 697 -> Predicted subsequence: tcattgaacggtataa
# Sample 698 -> Predicted subsequence: aagcacaagctgatga
# Sample 699 -> Predicted subsequence: gaacattttattgaaa
# Sample 700 -> Predicted subsequence: attctatgcaaaattg
# Sample 701 -> Predicted subsequence: tggctttggagactcc
# Sample 702 -> Predicted subsequence: gaagtgttaacagagg
# Sample 703 -> Predicted subsequence: agcttgtaaataaatt
# Sample 704 -> Predicted subsequence: aaatatctagtacaac
# Sample 705 -> Predicted subsequence: tcaattagatgaagag
# Sample 706 -> Predicted subsequence: atgatggtgtttattt
# Sample 707 -> Predicted subsequence: cctagtaataggtttc
# Sample 708 -> Predicted subsequence: ctactgaggagacatt
# Sample 709 -> Predicted subsequence: tgatggcacaacaagt
# Sample 710 -> Predicted subsequence: tacaatttttaaagat
# Sample 711 -> Predicted subsequence: aaagttatgtgcatgt
# Sample 712 -> Predicted subsequence: ctgataaaggagttgc
# Sample 713 -> Predicted subsequence: gaggtcatttattgaa
# Sample 714 -> Predicted subsequence: ttacaaaatgcaaaga
# Sample 715 -> Predicted subsequence: tagatctgttctctaa
# Sample 716 -> Predicted subsequence: ttatgtacatgggcac
# Sample 717 -> Predicted subsequence: ggtcaacaagacggca
# Sample 718 -> Predicted subsequence: tggccatgtagaaaca
# Sample 719 -> Predicted subsequence: ttgcctaggttcttta
# Sample 720 -> Predicted subsequence: ttacacagaatgttct
# Sample 721 -> Predicted subsequence: caccaaaagatcacat
# Sample 722 -> Predicted subsequence: ctaagtcactaactga
# Sample 723 -> Predicted subsequence: gtatttcccttaaatt
# Sample 724 -> Predicted subsequence: cgcttgttaaacaact
# Sample 725 -> Predicted subsequence: acaagcagctggtacg
# Sample 726 -> Predicted subsequence: tttgcctatgccaaca
# Sample 727 -> Predicted subsequence: cctaaaaagtctacta
# Sample 728 -> Predicted subsequence: gtatggtactgaagat
# Sample 729 -> Predicted subsequence: tcttcgtaagaacggt
# Sample 730 -> Predicted subsequence: acaaggaactgattac
# Sample 731 -> Predicted subsequence: taaaaacagtacaatt
# Sample 732 -> Predicted subsequence: atgatttcggtgattt
# Sample 733 -> Predicted subsequence: gttaaatttatctcaa
# Sample 734 -> Predicted subsequence: agctgataacaaattt
# Sample 735 -> Predicted subsequence: gatgattttgttgaaa
# Sample 736 -> Predicted subsequence: aagaatagcatagatg
# Sample 737 -> Predicted subsequence: gtccgtgttgcagccg
# Sample 738 -> Predicted subsequence: ttgatactagtttgtc
# Sample 739 -> Predicted subsequence: ttagctgtaccctata
# Sample 740 -> Predicted subsequence: tgcagaatgaattctc
# Sample 741 -> Predicted subsequence: tgttggtaccaattta
# Sample 742 -> Predicted subsequence: tcggcgttgtcctgct
# Sample 743 -> Predicted subsequence: tgtccaagacatgtga
# Sample 744 -> Predicted subsequence: cttcctcaaggaacaa
# Sample 745 -> Predicted subsequence: aagtttccatttggaa
# Sample 746 -> Predicted subsequence: acaatttataatttac
# Sample 747 -> Predicted subsequence: ttgccacctttgctca
# Sample 748 -> Predicted subsequence: ctttaaacacgcttgt
# Sample 749 -> Predicted subsequence: agccctaatgtgtaaa
# Sample 750 -> Predicted subsequence: ttcactattaagggtt
# Sample 751 -> Predicted subsequence: tagctgataacaaatt
# Sample 752 -> Predicted subsequence: tttatgaggctatgta
# Sample 753 -> Predicted subsequence: ttcaagaaaactggaa
# Sample 754 -> Predicted subsequence: caataacagttacacc
# Sample 755 -> Predicted subsequence: ctatgtcacttggtgt
# Sample 756 -> Predicted subsequence: ccagagaagaaacttg
# Sample 757 -> Predicted subsequence: acttccctatggtgct
# Sample 758 -> Predicted subsequence: agtcaccttttgttat
# Sample 759 -> Predicted subsequence: aactggactttattga
# Sample 760 -> Predicted subsequence: gtctatgctttaaggc
# Sample 761 -> Predicted subsequence: aaaactataggtccag
# Sample 762 -> Predicted subsequence: atttgtaattagaggt
# Sample 763 -> Predicted subsequence: ggtaaaatgaaagatc
# Sample 764 -> Predicted subsequence: tgaaggtaaaacattt
# Sample 765 -> Predicted subsequence: acataatcaggatgta
# Sample 766 -> Predicted subsequence: ccaacaacaacaaggc
# Sample 767 -> Predicted subsequence: ttttaatgttgtaaat
# Sample 768 -> Predicted subsequence: tggaggctgtgtgttc
# Sample 769 -> Predicted subsequence: atgatgatactctctg
# Sample 770 -> Predicted subsequence: tctgcctttccaacaa
# Sample 771 -> Predicted subsequence: agacagtgcttaaaaa
# Sample 772 -> Predicted subsequence: tgctgctcttcaacct
# Sample 773 -> Predicted subsequence: tttcccttaaattcca
# Sample 774 -> Predicted subsequence: tcggaacttgtcggcg
# Sample 775 -> Predicted subsequence: caggccacaaataggc
# Sample 776 -> Predicted subsequence: tgccacttggctatgt
# Sample 777 -> Predicted subsequence: attatttcaataaaaa
# Sample 778 -> Predicted subsequence: ttgatgtactgaagtc
# Sample 779 -> Predicted subsequence: gttgtcatctcgcaaa
# Sample 780 -> Predicted subsequence: ctggttctatatcttg
# Sample 781 -> Predicted subsequence: gctaccctcttgagtg
# Sample 782 -> Predicted subsequence: tcatgatggaaaagca
# Sample 783 -> Predicted subsequence: ttaaagaaagatgctc
# Sample 784 -> Predicted subsequence: cctatttctgaacatg
# Sample 785 -> Predicted subsequence: tgatgattatgtgtac
# Sample 786 -> Predicted subsequence: aacaagctttgtgaag
# Sample 787 -> Predicted subsequence: tgataaatattataat
# Sample 788 -> Predicted subsequence: gcacgctgcttctggt
# Sample 789 -> Predicted subsequence: tttggaaatgaagagt
# Sample 790 -> Predicted subsequence: tttatctaagtcacta
# Sample 791 -> Predicted subsequence: cactctccaagggtgt
# Sample 792 -> Predicted subsequence: taaaattaattttagt
# Sample 793 -> Predicted subsequence: tagacagtttcatcaa
# Sample 794 -> Predicted subsequence: ttggtgctgaccctat
# Sample 795 -> Predicted subsequence: taaacttaaagccttg
# Sample 796 -> Predicted subsequence: tgaaaattattctttt
# Sample 797 -> Predicted subsequence: ttgtttactcaaccgc
# Sample 798 -> Predicted subsequence: attagaacagtatgtc
# Sample 799 -> Predicted subsequence: taccaaaccaaccata
# Sample 800 -> Predicted subsequence: ctcttggaggttccgt
# Sample 801 -> Predicted subsequence: ttctaccagtgtctat
# Sample 802 -> Predicted subsequence: accatatccaaacgca
# Sample 803 -> Predicted subsequence: aacgatctaaatgaaa
# Sample 804 -> Predicted subsequence: aaagctattaagtgtg
# Sample 805 -> Predicted subsequence: ctttgttctttttttt
# Sample 806 -> Predicted subsequence: agtcagacaaatcgct
# Sample 807 -> Predicted subsequence: gtattgagtgaaatgg
# Sample 808 -> Predicted subsequence: ttgccacatagatcat
# Sample 809 -> Predicted subsequence: gcacaatcgtttttaa
# Sample 810 -> Predicted subsequence: tactatagcagagata
# Sample 811 -> Predicted subsequence: attgtcattacttcag
# Sample 812 -> Predicted subsequence: tggtgattcttcttca
# Sample 813 -> Predicted subsequence: gtgtttagctgtccac
# Sample 814 -> Predicted subsequence: ctttaaggaaggaagt
# Sample 815 -> Predicted subsequence: ctgttatgtctttaaa
# Sample 816 -> Predicted subsequence: ccagatccatcaaaac
# Sample 817 -> Predicted subsequence: atagtgcaacattacc
# Sample 818 -> Predicted subsequence: tcaagaatcctagggg
# Sample 819 -> Predicted subsequence: actgctcaaaattctg
# Sample 820 -> Predicted subsequence: agaatgctattagaaa
# Sample 821 -> Predicted subsequence: gggattatcctaaatg
# Sample 822 -> Predicted subsequence: taattattatgaggac
# Sample 823 -> Predicted subsequence: caatggtactaagagg
# Sample 824 -> Predicted subsequence: aatttacaacacagac
# Sample 825 -> Predicted subsequence: tcagaggctgctcgtg
# Sample 826 -> Predicted subsequence: ctgaaattgttgacac
# Sample 827 -> Predicted subsequence: tgctcgtacgtggctt
# Sample 828 -> Predicted subsequence: agtttgttcgcattca
# Sample 829 -> Predicted subsequence: ctatgccttcgaacat
# Sample 830 -> Predicted subsequence: agagtcgaatgtacaa
# Sample 831 -> Predicted subsequence: agacggtgctttactt
# Sample 832 -> Predicted subsequence: gaccccaaaatcagcg
# Sample 833 -> Predicted subsequence: tttggctttgctggaa
# Sample 834 -> Predicted subsequence: caatgctttaaaatgt
# Sample 835 -> Predicted subsequence: gtaaaggtagacttat
# Sample 836 -> Predicted subsequence: tgttgttttagatttc
# Sample 837 -> Predicted subsequence: taccagatgattttac
# Sample 838 -> Predicted subsequence: tcaatttaaacacctc
# Sample 839 -> Predicted subsequence: agtttcacctaaactg
# Sample 840 -> Predicted subsequence: catgcaccatatggaa
# Sample 841 -> Predicted subsequence: ggctactaacaatgcc
# Sample 842 -> Predicted subsequence: ttgctcttctggaaca
# Sample 843 -> Predicted subsequence: gatggctctattattc
# Sample 844 -> Predicted subsequence: taccctgacaaagttt
# Sample 845 -> Predicted subsequence: gagacacttggtgtcc
# Sample 846 -> Predicted subsequence: cattaataacactgtt
# Sample 847 -> Predicted subsequence: ggtggtgacggtaaaa
# Sample 848 -> Predicted subsequence: tacgaacttatgtact
# Sample 849 -> Predicted subsequence: tattgttaatggtgtt
# Sample 850 -> Predicted subsequence: ttcaattattataaga
# Sample 851 -> Predicted subsequence: gatgatgatagtcaac
# Sample 852 -> Predicted subsequence: taccagagcaaaagta
# Sample 853 -> Predicted subsequence: caaatgaatcttaagt
# Sample 854 -> Predicted subsequence: gtagtacatttattag
# Sample 855 -> Predicted subsequence: tgatgccaactatttt
# Sample 856 -> Predicted subsequence: aagtttaaggaaggtg
# Sample 857 -> Predicted subsequence: attatacttaaaccag
# Sample 858 -> Predicted subsequence: ctagacttagttttaa
# Sample 859 -> Predicted subsequence: acatcctaatcaggag
# Sample 860 -> Predicted subsequence: ttaaggaaggtgtaga
# Sample 861 -> Predicted subsequence: ttgatacttataacct
# Sample 862 -> Predicted subsequence: ccatctattatctcta
# Sample 863 -> Predicted subsequence: gttgatttaggtgaca
# Sample 864 -> Predicted subsequence: tgaatgcagcaatctt
# Sample 865 -> Predicted subsequence: tccaggcagctctaaa
# Sample 866 -> Predicted subsequence: gttatacattttggtg
# Sample 867 -> Predicted subsequence: caacacatttgtgtct
# Sample 868 -> Predicted subsequence: ccgtttctatagatta
# Sample 869 -> Predicted subsequence: ttaagaatattgatgg
# Sample 870 -> Predicted subsequence: ctaacataggttgtaa
# Sample 871 -> Predicted subsequence: acgggtacgctgcttg
# Sample 872 -> Predicted subsequence: gtagacttatgaaaac
# Sample 873 -> Predicted subsequence: acttgtacttgacatt
# Sample 874 -> Predicted subsequence: cattccttaatggttc
# Sample 875 -> Predicted subsequence: gtagacttatttagaa
# Sample 876 -> Predicted subsequence: cagtgcttaaaaagtg
# Sample 877 -> Predicted subsequence: tctggacaatctacac
# Sample 878 -> Predicted subsequence: cttagttttaaggaat
# Sample 879 -> Predicted subsequence: aaattttgtatttccc
# Sample 880 -> Predicted subsequence: tgatagtgcggaagtt
# Sample 881 -> Predicted subsequence: attacaccatgttctt
# Sample 882 -> Predicted subsequence: caacacagtttatgat
# Sample 883 -> Predicted subsequence: tttaccaaccaccaca
# Sample 884 -> Predicted subsequence: tgttgttattaaagtc
# Sample 885 -> Predicted subsequence: tgttgctattcatgca
# Sample 886 -> Predicted subsequence: ccatgcaacgtaagtt
# Sample 887 -> Predicted subsequence: aaagttggataatgat
# Sample 888 -> Predicted subsequence: tcccttccatcatatg
# ...
# Sample 9734 -> Predicted subsequence: gaaaacagggtaattt
# Sample 9735 -> Predicted subsequence: tagtgtttttaacatt
# Sample 9736 -> Predicted subsequence: aaattccataatcaag
# Sample 9737 -> Predicted subsequence: tattacagagcaaggg
# Sample 9738 -> Predicted subsequence: cggttgtaattcatca
# Sample 9739 -> Predicted subsequence: caatttcaagtgtttt
# Sample 9740 -> Predicted subsequence: cagtggttgttaatgc
# Sample 9741 -> Predicted subsequence: aatgcaaagaatgcta
# Sample 9742 -> Predicted subsequence: ttgtgctagtgagtac
# Sample 9743 -> Predicted subsequence: ttaaaatatttgccta
# Sample 9744 -> Predicted subsequence: ccacgcacattgctaa
# Sample 9745 -> Predicted subsequence: ctacactatgtcactt
# Sample 9746 -> Predicted subsequence: cttatgttggttgcca
# Sample 9747 -> Predicted subsequence: attcttggaactgttt
# Sample 9748 -> Predicted subsequence: aacattaaaccagtac
# Sample 9749 -> Predicted subsequence: tacaatgtacatttgt
# Sample 9750 -> Predicted subsequence: ctgtgcaaaggaaatt
# Sample 9751 -> Predicted subsequence: acctagagtttttagt
# Sample 9752 -> Predicted subsequence: tggaacacttttacaa
# Sample 9753 -> Predicted subsequence: atgttcaactcagggt
# Sample 9754 -> Predicted subsequence: aaaagaaaatgactct
# Sample 9755 -> Predicted subsequence: attacctgcaccacgc
# Sample 9756 -> Predicted subsequence: tggcttcacatatgta
# Sample 9757 -> Predicted subsequence: gtaaccctaaagctat
# Sample 9758 -> Predicted subsequence: caagatggtatttcta
# Sample 9759 -> Predicted subsequence: ccaatgtttaccttaa
# Sample 9760 -> Predicted subsequence: ttttcttgctttcgtg
# Sample 9761 -> Predicted subsequence: cgatttgtgcaccact
# Sample 9762 -> Predicted subsequence: gtcatgtctaaacata
# Sample 9763 -> Predicted subsequence: attacaggtggtgttg
# Sample 9764 -> Predicted subsequence: ctattccttgttttaa
# Sample 9765 -> Predicted subsequence: agcgcttcagcgttct
# Sample 9766 -> Predicted subsequence: catatatagtgggtga
# Sample 9767 -> Predicted subsequence: ttgtgaaattgtcggt
# Sample 9768 -> Predicted subsequence: aacaatctagttgtaa
# Sample 9769 -> Predicted subsequence: agcttatgagcaggct
# Sample 9770 -> Predicted subsequence: gtagtctttaatggtg
# Sample 9771 -> Predicted subsequence: tgaagaagctgcgctg
# Sample 9772 -> Predicted subsequence: gctatagcctcagagt
# Sample 9773 -> Predicted subsequence: tgataagtactttgat
# Sample 9774 -> Predicted subsequence: ttggtgtactgacatt
# Sample 9775 -> Predicted subsequence: actgtcttatggtatt
# Sample 9776 -> Predicted subsequence: ataatgttactgactt
# Sample 9777 -> Predicted subsequence: tggtgttgaaggtttt
# Sample 9778 -> Predicted subsequence: cacaagaaaagaactt
# Sample 9779 -> Predicted subsequence: gcatctgtttatgctt
# Sample 9780 -> Predicted subsequence: tggtagtacatttatt
# Sample 9781 -> Predicted subsequence: aaagacaaatcagctc
# Sample 9782 -> Predicted subsequence: gcaactgtacatacag
# Sample 9783 -> Predicted subsequence: tgactaccagattggt
# Sample 9784 -> Predicted subsequence: agtggttatttaaaac
# Sample 9785 -> Predicted subsequence: tggacatatcagcatc
# Sample 9786 -> Predicted subsequence: gtgcgaataattgcac
# Sample 9787 -> Predicted subsequence: accttttgaaattaaa
# Sample 9788 -> Predicted subsequence: taaaagccccaaaaga
# Sample 9789 -> Predicted subsequence: aggtaaacctttggaa
# Sample 9790 -> Predicted subsequence: atccttcactgtagaa
# Sample 9791 -> Predicted subsequence: caattattataagaaa
# Sample 9792 -> Predicted subsequence: tcatcaacttgtatga
# Sample 9793 -> Predicted subsequence: gtccagcatgtcacaa
# Sample 9794 -> Predicted subsequence: ttatgattacttagtt
# Sample 9795 -> Predicted subsequence: tttatgcatttgcatc
# Sample 9796 -> Predicted subsequence: acaaaattgccgataa
# Sample 9797 -> Predicted subsequence: tataatatgagagtta
# Sample 9798 -> Predicted subsequence: aaattcacagatggtg
# Sample 9799 -> Predicted subsequence: gtgttcccttgaacat
# Sample 9800 -> Predicted subsequence: ctacagtgttcccact
# Sample 9801 -> Predicted subsequence: gaaatgcttgcacatg
# Sample 9802 -> Predicted subsequence: cattcaaacaaattgt
# Sample 9803 -> Predicted subsequence: tattagtttttctgtt
# Sample 9804 -> Predicted subsequence: atctatacagaactgg
# Sample 9805 -> Predicted subsequence: cgcagtggctaactaa
# Sample 9806 -> Predicted subsequence: taaaatcagcaccttt
# Sample 9807 -> Predicted subsequence: tacaacgtgttgtagc
# Sample 9808 -> Predicted subsequence: tgtcagatatagatta
# Sample 9809 -> Predicted subsequence: gaatatgtctctcagc
# Sample 9810 -> Predicted subsequence: tgagaatttgactaaa
# Sample 9811 -> Predicted subsequence: ttcaacatgccaattt
# Sample 9812 -> Predicted subsequence: aacactccaacaaata
# Sample 9813 -> Predicted subsequence: gatttcatacaaacca
# Sample 9814 -> Predicted subsequence: gctgaacttgcaaaga
# Sample 9815 -> Predicted subsequence: tggcaactagcactct
# Sample 9816 -> Predicted subsequence: agattgaaccagcttg
# Sample 9817 -> Predicted subsequence: gcattagtgtctgatg
# Sample 9818 -> Predicted subsequence: cgctgttgatgcacta
# Sample 9819 -> Predicted subsequence: tcagacaaatcgctcc
# Sample 9820 -> Predicted subsequence: ctaaacactgtcttca
# Sample 9821 -> Predicted subsequence: acagaatgttctctat
# Sample 9822 -> Predicted subsequence: tattgttatgatacca
# Sample 9823 -> Predicted subsequence: ggaagagaatcagcaa
# Sample 9824 -> Predicted subsequence: tacctaaaggcataat
# Sample 9825 -> Predicted subsequence: tataatttacttaagg
# Sample 9826 -> Predicted subsequence: cgtgaccttggtgctt
# Sample 9827 -> Predicted subsequence: tgattatgtgtacctt
# Sample 9828 -> Predicted subsequence: ctaatactgtgatctg
# Sample 9829 -> Predicted subsequence: gctaatggacacgttt
# Sample 9830 -> Predicted subsequence: agtttattgtttctta
# Sample 9831 -> Predicted subsequence: ttaaaaatctgaattc
# Sample 9832 -> Predicted subsequence: agcttttgataaaagt
# Sample 9833 -> Predicted subsequence: tatacagtttcctgtt
# Sample 9834 -> Predicted subsequence: tagcttgttttgtgct
# Sample 9835 -> Predicted subsequence: aacattaaattgttgg
# Sample 9836 -> Predicted subsequence: taaagagacgtgtagt
# Sample 9837 -> Predicted subsequence: aaaatacgtgtgatgg
# Sample 9838 -> Predicted subsequence: tgtattgttcttttta
# Sample 9839 -> Predicted subsequence: agggttgaaaagaaaa
# Sample 9840 -> Predicted subsequence: cccgcgaagaagctat
# Sample 9841 -> Predicted subsequence: tgttatgtctttaaaa
# Sample 9842 -> Predicted subsequence: ctgacttttcaagtga
# Sample 9843 -> Predicted subsequence: gccaaccaatttaata
# Sample 9844 -> Predicted subsequence: gtttgtgtatctacta
# Sample 9845 -> Predicted subsequence: ttgcttttcaaactgt
# Sample 9846 -> Predicted subsequence: taaaacttgtggacaa
# Sample 9847 -> Predicted subsequence: gtccagaacaaaccca
# Sample 9848 -> Predicted subsequence: taaactgataaatatt
# Sample 9849 -> Predicted subsequence: aattgaccgcctcaat
# Sample 9850 -> Predicted subsequence: tggttaataattaatc
# Sample 9851 -> Predicted subsequence: ttatgtccctgcacaa
# Sample 9852 -> Predicted subsequence: agattccaacggtact
# Sample 9853 -> Predicted subsequence: tgccaattcaactgta
# Sample 9854 -> Predicted subsequence: atgttttacctaatga
# Sample 9855 -> Predicted subsequence: tagtgatgaagttgcg
# Sample 9856 -> Predicted subsequence: gttatcttgccactgc
# Sample 9857 -> Predicted subsequence: tttaacatttgtcaag
# Sample 9858 -> Predicted subsequence: ttttaagtttgtatgt
# Sample 9859 -> Predicted subsequence: tctgatgattacatag
# Sample 9860 -> Predicted subsequence: attgctttgcttgtac
# Sample 9861 -> Predicted subsequence: aatattggtgaacaga
# Sample 9862 -> Predicted subsequence: agcgtctgtttactac
# Sample 9863 -> Predicted subsequence: ctattactctgacagt
# Sample 9864 -> Predicted subsequence: ttgttaataattggtt
# Sample 9865 -> Predicted subsequence: caaatcagctggtttt
# Sample 9866 -> Predicted subsequence: ctaatctttacaaaat
# Sample 9867 -> Predicted subsequence: aaatgttaagtgacac
# Sample 9868 -> Predicted subsequence: actttttgcatttctt
# Sample 9869 -> Predicted subsequence: aaagaaagatagaatg
# Sample 9870 -> Predicted subsequence: ggttgtgttcccttga
# Sample 9871 -> Predicted subsequence: gaatgtggctaaatct
# Sample 9872 -> Predicted subsequence: gttcagagtttattct
# Sample 9873 -> Predicted subsequence: ggtgaagtaccagttt
# Sample 9874 -> Predicted subsequence: aacaaatgtgtcaatt
# Sample 9875 -> Predicted subsequence: gactattgactataca
# Sample 9876 -> Predicted subsequence: ctgttgaacaagacaa
# Sample 9877 -> Predicted subsequence: ctggttacagagaagg
# Sample 9878 -> Predicted subsequence: tggtgtttattctgtt
# Sample 9879 -> Predicted subsequence: gattgtacaaatgtta
# Sample 9880 -> Predicted subsequence: ctagtggtagatgggt
# Sample 9881 -> Predicted subsequence: tctatacagaactgga
# Sample 9882 -> Predicted subsequence: gacagatgtcttgtgc
# Sample 9883 -> Predicted subsequence: taccaactcaaactgt
# Sample 9884 -> Predicted subsequence: aatgagttgtgaggat
# Sample 9885 -> Predicted subsequence: cagacaaggaactgat
# Sample 9886 -> Predicted subsequence: tttctccaaacaattg
# Sample 9887 -> Predicted subsequence: agaacattcttggaat
# Sample 9888 -> Predicted subsequence: taaacactacacaccc
# Sample 9889 -> Predicted subsequence: ggcggcagtcaagcct
# Sample 9890 -> Predicted subsequence: atttctgaacatgact
# Sample 9891 -> Predicted subsequence: gcctggagatcaattt
# Sample 9892 -> Predicted subsequence: aatgaatctctcatcg
# Sample 9893 -> Predicted subsequence: attacaaacattggcc
# Sample 9894 -> Predicted subsequence: cgataattttaagttt
# Sample 9895 -> Predicted subsequence: aacctaggacttttct
# Sample 9896 -> Predicted subsequence: ttatgaaagtttacgc
# Sample 9897 -> Predicted subsequence: ccctgtgggttttaca
# Sample 9898 -> Predicted subsequence: aagatgttgttgaatg
# Sample 9899 -> Predicted subsequence: cacatatgtattgttc
# Sample 9900 -> Predicted subsequence: acaataccttcacact
# Sample 9901 -> Predicted subsequence: acaaagttttcagatc
# Sample 9902 -> Predicted subsequence: tttcttggtacaggct
# Sample 9903 -> Predicted subsequence: aagctggacttcccta
# Sample 9904 -> Predicted subsequence: aatttattgtccagca
# Sample 9905 -> Predicted subsequence: acttttcaacaaagtg
# Sample 9906 -> Predicted subsequence: gattttgtgacttaaa
# Sample 9907 -> Predicted subsequence: agcacttaagggtggt
# Sample 9908 -> Predicted subsequence: cttgtcacaccgtttc
# Sample 9909 -> Predicted subsequence: cagtataattaataac
# Sample 9910 -> Predicted subsequence: acatttgtcacgcact
# Sample 9911 -> Predicted subsequence: agatttggatgatttc
# Sample 9912 -> Predicted subsequence: aaggcgttccaattaa
# Sample 9913 -> Predicted subsequence: atttgcctatgccaac
# Sample 9914 -> Predicted subsequence: actgaagattaatgcg
# Sample 9915 -> Predicted subsequence: tcctatataattccgc
# Sample 9916 -> Predicted subsequence: cattcagtacggtcgt
# Sample 9917 -> Predicted subsequence: agtctttgaatgtggc
# Sample 9918 -> Predicted subsequence: gatggttatgttcaca
# Sample 9919 -> Predicted subsequence: caaacgtaatagagca
# Sample 9920 -> Predicted subsequence: tcagagcttctgctaa
# Sample 9921 -> Predicted subsequence: agactttatgagtgtc
# Sample 9922 -> Predicted subsequence: acaaaggacttccttg
# Sample 9923 -> Predicted subsequence: cgcagggaatggataa
# Sample 9924 -> Predicted subsequence: tcgcgcattggcatgg
# Sample 9925 -> Predicted subsequence: agttcttcacgacatc
# Sample 9926 -> Predicted subsequence: cagacaacacatttgt
# Sample 9927 -> Predicted subsequence: gtattaggtttgaaaa
# Sample 9928 -> Predicted subsequence: ccaaccatatccaaac
# Sample 9929 -> Predicted subsequence: gcagataacaactgtt
# Sample 9930 -> Predicted subsequence: atccgtttatgattga
# Sample 9931 -> Predicted subsequence: ctatgtgatagacgtg
# Sample 9932 -> Predicted subsequence: cttattacagaaggta
# Sample 9933 -> Predicted subsequence: gtacatttggctaggt
# Sample 9934 -> Predicted subsequence: gtctgtgtggaaacta
# Sample 9935 -> Predicted subsequence: cttctgtggccctgat
# Sample 9936 -> Predicted subsequence: ccatgagcagtgctga
# Sample 9937 -> Predicted subsequence: ttgatggttattttaa
# Sample 9938 -> Predicted subsequence: ttatctcaacctgtgc
# Sample 9939 -> Predicted subsequence: gagatattactaatta
# Sample 9940 -> Predicted subsequence: acctaaatagaggtat
# Sample 9941 -> Predicted subsequence: gatgtggtgcttgcat
# Sample 9942 -> Predicted subsequence: ctactaacatagttac
# Sample 9943 -> Predicted subsequence: tccatcaaaaccaagc
# Sample 9944 -> Predicted subsequence: ttatgtacaaaggact
# Sample 9945 -> Predicted subsequence: atgtggctcagctact
# Sample 9946 -> Predicted subsequence: gtagctggtggtattg
# Sample 9947 -> Predicted subsequence: ctagttgcaactgcag
# Sample 9948 -> Predicted subsequence: ttagactcattcaagg
# Sample 9949 -> Predicted subsequence: ctataagacatgtacg
# Sample 9950 -> Predicted subsequence: atgccttcaaactcaa
# Sample 9951 -> Predicted subsequence: cactagtctctagtca
# Sample 9952 -> Predicted subsequence: ctgtgggttttacact
# Sample 9953 -> Predicted subsequence: gataaccctgtcctac
# Sample 9954 -> Predicted subsequence: ggttaccctaacatgt
# Sample 9955 -> Predicted subsequence: tgcgttagcttactac
# Sample 9956 -> Predicted subsequence: tggtgctgaccctata
# Sample 9957 -> Predicted subsequence: tttgaaaaaatggttt
# Sample 9958 -> Predicted subsequence: cattagggaggacttg
# Sample 9959 -> Predicted subsequence: tgttgtaacaacaaag
# Sample 9960 -> Predicted subsequence: gtgctatctaacctta
# Sample 9961 -> Predicted subsequence: ggtgtttaccaatgtg
# Sample 9962 -> Predicted subsequence: accaacatgaagaaac
# Sample 9963 -> Predicted subsequence: atgctggcttcatcaa
# Sample 9964 -> Predicted subsequence: aaattgccgataagta
# Sample 9965 -> Predicted subsequence: aaaaacaacaaaagtt
# Sample 9966 -> Predicted subsequence: gaaaagctgtctttat
# Sample 9967 -> Predicted subsequence: gttgcaactgcagaag
# Sample 9968 -> Predicted subsequence: aattgtgatacattct
# Sample 9969 -> Predicted subsequence: aaaactctttgaccgt
# Sample 9970 -> Predicted subsequence: acttactaatatgttt
# Sample 9971 -> Predicted subsequence: gttagtgacattgaca
# Sample 9972 -> Predicted subsequence: tccagaaactaacatt
# Sample 9973 -> Predicted subsequence: tgatactagtttgtct
# Sample 9974 -> Predicted subsequence: tcatccctactataac
# Sample 9975 -> Predicted subsequence: gtgtggtcactataaa
# Sample 9976 -> Predicted subsequence: agtatataaaatggcc
# Sample 9977 -> Predicted subsequence: gtattgctactgtacg
# Sample 9978 -> Predicted subsequence: atcgtaaaaacagatg
# Sample 9979 -> Predicted subsequence: ggtgattgtgaagaag
# Sample 9980 -> Predicted subsequence: tgaagaaacaatttat
# Sample 9981 -> Predicted subsequence: tagcgtacttcttttt
# Sample 9982 -> Predicted subsequence: atgccttcgaacatat
# Sample 9983 -> Predicted subsequence: gcatctcaaggtctag
# Sample 9984 -> Predicted subsequence: actaggtttcaaactt
# Sample 9985 -> Predicted subsequence: acacattaacattagc
# Sample 9986 -> Predicted subsequence: aacaatgctagggaga
# Sample 9987 -> Predicted subsequence: cttttggtgatgacac
# Sample 9988 -> Predicted subsequence: cctaagactaaaaatg
# Sample 9989 -> Predicted subsequence: tgatggctttatgggt
# Sample 9990 -> Predicted subsequence: aacactcgctacttgt
# Sample 9991 -> Predicted subsequence: ccttaatggttcatgt
# Sample 9992 -> Predicted subsequence: ttaggaggtatgagct
# Sample 9993 -> Predicted subsequence: gtggaacctcatcagg
# Sample 9994 -> Predicted subsequence: ataattagagaaaaca
# Sample 9995 -> Predicted subsequence: aatgtgcctttcaact
# Sample 9996 -> Predicted subsequence: ggcaaaattcaagact
# Sample 9997 -> Predicted subsequence: acaaagccttacatta
# Sample 9998 -> Predicted subsequence: tcctctggctgttatg
# Sample 9999 -> Predicted subsequence: ctttctggataacaat
#                                                  id  Position  \
# 0               Eta|hCoV-19/Canada/ABPHL-07105/2021       977
# 1         Zeta|hCoV-19/Brazil/PB-FIOCRUZ-29646/2020      7804
# 2        Kappa|hCoV-19/Germany/MV-RKI-I-138459/2021     29623
# 3          Omicron|hCoV-19/France/HDF-IPP05865/2022     11854
# 4            Kappa|hCoV-19/India/KA-RFNB-10512/2021        37
# 5             Zeta|hCoV-19/Brazil/SP-HIAE-ID07/2020     12722
# 6            Eta|hCoV-19/Canada/SK-RRPL-132437/2021      5246
# 7           Alpha|hCoV-19/England/ALDP-146DB54/2021     27501
# 8  Zeta|hCoV-19/Mexico/JAL-InDRE_FB14245_S1793/2021      8183
# 9            Alpha|hCoV-19/England/QEUH-F6B6E4/2021     22914
#
#   Original_Sequence Predicted_Sequence  Overall_Accuracy
# 0  aaattaaattggcaaa   aaattaaattggcaaa               1.0
# 1  gacattctctctctca   gacattctctctctca               1.0
# 2  ttaactttaatctcac   ttaactttaatctcac               1.0
# 3  aaattgtgggctcaat   aaattgtgggctcaat               1.0
# 4  atctgtgtggctgtca   atctgtgtggctgtca               1.0
# 5  tgcttgcactgatgac   tgcttgcactgatgac               1.0
# 6  cattgttaacactcca   cattgttaacactcca               1.0
# 7  actcaatttgcttttg   actcaatttgcttttg               1.0
# 8  gttgttgaatgtctta   gttgttgaatgtctta               1.0
# 9  cggtagcacaccttgt   cggtagcacaccttgt               1.0

# %%
df_results
# Out:
#                                               id  Position Original_Sequence  \
# 0            Eta|hCoV-19/Canada/ABPHL-07105/2021       977  aaattaaattggcaaa
# 1      Zeta|hCoV-19/Brazil/PB-FIOCRUZ-29646/2020      7804  gacattctctctctca
# 2     Kappa|hCoV-19/Germany/MV-RKI-I-138459/2021     29623  ttaactttaatctcac
# 3       Omicron|hCoV-19/France/HDF-IPP05865/2022     11854  aaattgtgggctcaat
# 4         Kappa|hCoV-19/India/KA-RFNB-10512/2021        37  atctgtgtggctgtca
# ...                                          ...       ...               ...
# 9995   Delta|hCoV-19/USA/NY-MSHSPSP-PV33493/2021      1142  aatgtgcctttcaact
# 9996       Delta|hCoV-19/Wales/MILK-2D2FACE/2021     24299  ggcaaaattcaagact
# 9997     Gamma|hCoV-19/Spain/CT-HUVH-E22723/2021     14184  acaaagccttacatta
# 9998  Alpha|hCoV-19/Germany/NW-RKI-I-146006/2021     26625  tcctctggctgttatg
# 9999     Gamma|hCoV-19/Argentina/INEI103533/2021      9658  ctttctggataacaat
#
#      Predicted_Sequence  Overall_Accuracy
# 0      aaattaaattggcaaa               1.0
# 1      gacattctctctctca               1.0
# 2      ttaactttaatctcac               1.0
# 3      aaattgtgggctcaat               1.0
# 4      atctgtgtggctgtca               1.0
# ...                 ...               ...
# 9995   aatgtgcctttcaact               1.0
# 9996   ggcaaaattcaagact               1.0
# 9997   acaaagccttacatta               1.0
# 9998   tcctctggctgttatg               1.0
# 9999   ctttctggataacaat               1.0
#
# [10000 rows x 5 columns]

# %%
for i, seq in enumerate(predicted_sequences):
    print(f"Sample {i} -> Predicted subsequence: {seq}")



df_results = pd.DataFrame({
    "Position": df_build["targetpos"],
    "Record_Num": df_build["id"],
    "Original_Sequence": df_build["subseq"],
    "masked_og_seq" : df_build["maskseq"],
    "Predicted_Sequence": predicted_sequences
})

print(df_results.head(10))

output_file = "HIV_predictions.csv"
df_results.to_csv("HIV_predictions.csv")
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df_results = pd.DataFrame({
    "Position": df_build["targetpos"],
    "Record_Num": df_build["id"],
    "Original_Sequence": df_build["subseq"],
    "Predicted_Sequence": predicted_sequences
})


df_results.to_csv("HIVpredictions.csv")

# %%
df_build
# Out:
#         Unnamed: 0        id  startpos  maskpos  targetpos            subseq  \
# 0           148553  MK115290      9059       16         13  cagttggacccccaaa
# 1            57436  AF286238         4       16         12  tcgaagcgaagtacca
# 2            90505  JQ316127      1579       16          5  gtattgccctatcagc
# 3            65568  MK303350      5940       16         12  caagcacaaatgatag
# 4           145156  MH897917      6741       16         11  cgatttccggataaaa
# ...            ...       ...       ...      ...        ...               ...
# 155533      101001  MF373131      6872       16          8  gacaataggagaaata
# 155534      144749  MH897912      6014       16          2  caattcgaccgagtcg
# 155535      110822  MF373175      5357       16          3  aaaataggaaactgtt
# 155536       45060  FJ388910      1135       16          1  aggggggcaataagaa
# 155537       19083  JN692473      7163       16          5  cggtagtgaaatcttc
#
#                  maskseq   n_a   n_c   n_t  ...  moment_t_6   moment_g_6  \
# 0       cagttggaccccNaaa  5.25  5.25  2.25  ...   11.880903     2.753992
# 1       tcgaagcgaagNacca  6.25  4.25  1.25  ...  216.255005     1.828590
# 2       gtatNgccctatcagc  3.25  5.25  4.25  ...    6.567249   296.768399
# 3       caagcacaaatNatag  8.25  3.25  2.25  ...    0.276245  1131.501073
# 4       cgatttccggNtaaaa  5.25  3.25  4.25  ...    4.099389    19.787065
# ...                  ...   ...   ...   ...  ...         ...          ...
# 155533  gacaataNgagaaata  9.25  1.25  2.25  ...  203.352556    56.089312
# 155534  cNattcgaccgagtcg  3.25  5.25  3.25  ...   82.856590     7.719815
# 155535  aaNataggaaactgtt  7.25  1.25  4.25  ...   30.853112    11.005265
# 155536  Nggggggcaataagaa  6.25  1.25  1.25  ...  122.070312     2.318020
# 155537  cggtNgtgaaatcttc  3.25  3.25  5.25  ...    4.320994     0.326410
#
#         moment_a_7   moment_c_7  moment_t_7  moment_g_7  \
# 0       -50.471244   -16.487984   20.882172    2.671894
# 1         0.832662   -58.867382    0.000000   -0.190982
# 2      -122.169716     1.531735    0.303146  430.250722
# 3         0.057865     0.254329    0.003227  -52.872398
# 4       -57.684677   -12.287030    5.066673  -30.234087
# ...            ...          ...         ...         ...
# 155533   -0.072027     0.000000   13.008142  -95.861896
# 155534   -3.958981    -1.950136  162.016656   -5.838140
# 155535   -0.026205     0.000000  -51.285933   12.577646
# 155536   -2.709518     0.000000    0.000000    2.613394
# 155537   -0.154598 -1552.834887   -3.778675    0.125281
#
#                                    pos_a               pos_c  \
# 0                     [2, 8, 14, 15, 16]  [1, 9, 10, 11, 12]
# 1                  [4, 5, 9, 10, 13, 16]      [2, 7, 14, 15]
# 2                            [3, 11, 14]   [7, 8, 9, 13, 16]
# 3            [2, 3, 6, 8, 9, 10, 13, 15]           [1, 5, 7]
# 4                    [3, 13, 14, 15, 16]           [1, 7, 8]
# ...                                  ...                 ...
# 155533  [2, 4, 5, 7, 10, 12, 13, 14, 16]                 [3]
# 155534                        [3, 8, 12]   [1, 6, 9, 10, 15]
# 155535           [1, 2, 4, 6, 9, 10, 11]                [12]
# 155536           [9, 10, 12, 13, 15, 16]                 [8]
# 155537                       [9, 10, 11]         [1, 13, 16]
#
#                          pos_g                  pos_t
# 0                    [3, 6, 7]             [4, 5, 13]
# 1                [3, 6, 8, 11]                [1, 12]
# 2                   [1, 6, 15]      [2, 4, 5, 10, 12]
# 3                      [4, 16]           [11, 12, 14]
# 4                   [2, 9, 10]      [4, 5, 6, 11, 12]
# ...                        ...                    ...
# 155533              [1, 9, 11]             [6, 8, 15]
# 155534         [7, 11, 13, 16]          [2, 4, 5, 14]
# 155535              [7, 8, 14]     [3, 5, 13, 15, 16]
# 155536  [2, 3, 4, 5, 6, 7, 14]                [1, 11]
# 155537            [2, 3, 6, 8]  [4, 5, 7, 12, 14, 15]
#
# [155538 rows x 43 columns]

# %%
df_results = pd.DataFrame({
    "id": df_build["id"],
    "Position": df_build["maskpos"],
    "Maskpos": df_build["targetpos"],
    "Original_Sequence": df_build["subseq"].str.upper(),
    "Predicted_Sequence": predicted_sequences
})

# %%
df_results['Position'].value_counts(dropna=False)
# Out:
# Position
# 16    155538
# Name: count, dtype: int64

# %%
df_results['Target_nu'] = df_results.apply(lambda row: row['Original_Sequence'][row['Maskpos'] - 1], axis=1)
df_results['Predicted_nu'] = df_results.apply(lambda row: row['Predicted_Sequence'][row['Maskpos'] - 1], axis=1)
df_results['correct'] = np.where(df_results['Target_nu'] == df_results['Predicted_nu'],1,0)
df_results
# Out:
#               id  Position  Maskpos Original_Sequence Predicted_Sequence  \
# 0       MK115290        16       13  CAGTTGGACCCCCAAA   CAGTTGGACCCCAAAA
# 1       AF286238        16       12  TCGAAGCGAAGTACCA   TCGAAGCGAAGCACCA
# 2       JQ316127        16        5  GTATTGCCCTATCAGC   GTATTGCCCTATCAGC
# 3       MK303350        16       12  CAAGCACAAATGATAG   CAAGCACAAATTATAG
# 4       MH897917        16       11  CGATTTCCGGATAAAA   CGATTTCCGGATAAAA
# ...          ...       ...      ...               ...                ...
# 155533  MF373131        16        8  GACAATAGGAGAAATA   GACAATAGGAGAAATA
# 155534  MH897912        16        2  CAATTCGACCGAGTCG   CTATTCGACCGAGTCG
# 155535  MF373175        16        3  AAAATAGGAAACTGTT   AAAATAGGAAACTGTT
# 155536  FJ388910        16        1  AGGGGGGCAATAAGAA   TGGGGGGCAATAAGAA
# 155537  JN692473        16        5  CGGTAGTGAAATCTTC   CGGTGGTGAAATCTTC
#
#        Target_nu Predicted_nu  correct
# 0              C            A        0
# 1              T            C        0
# 2              T            T        1
# 3              G            T        0
# 4              A            A        1
# ...          ...          ...      ...
# 155533         G            G        1
# 155534         A            T        0
# 155535         A            A        1
# 155536         A            T        0
# 155537         A            G        0
#
# [155538 rows x 8 columns]

# %%
df_results[['Maskpos', 'correct']].value_counts(dropna=False)
# Out:
# Maskpos  correct
# 1        0          6500
# 2        0          6453
# 3        0          6418
# 16       0          6315
# 11       0          6297
# 5        0          6290
# 7        0          6281
# 8        0          6268
# 4        0          6266
# 10       0          6264
# 6        0          6259
# 12       0          6249
# 14       0          6247
# 15       0          6218
# 9        0          6211
# 13       0          6193
# 15       1          3559
# 13       1          3555
# 14       1          3515
# 9        1          3506
# 12       1          3486
# 16       1          3478
# 10       1          3459
# 6        1          3446
# 8        1          3443
# 11       1          3433
# 7        1          3427
# 4        1          3425
# 5        1          3405
# 3        1          3269
# 2        1          3227
# 1        1          3176
# Name: count, dtype: int64

# %%
df_results[(df_results['id'] == 'MK115290') & (df_results['Position'] == 9072)]
# Out:
#          id  Position  Maskpos Original_Sequence Predicted_Sequence Target_nu  \
# 0  MK115290      9072       13  CAGTTGGACCCCCAAA   CAGTTGGACCCCAAAA         C
#
#   Predicted_nu  correct
# 0            A        0

# %%
df_results[(df_results['id'] == 'MK115290') & (df_results['Position'] == 16)][['Predicted_nu']].value_counts(dropna=False)
# Out:
# Predicted_nu
# A               27
# C                8
# G                7
# T                4
# Name: count, dtype: int64

# %%
predicted_sequences
# Out:
# ['TCAACAAAGCCTTATA',
#  'TGTGTAATGCTGAAAA',
#  'TAAGAGGCAAGAAATT',
#  'CTGAAAGGGGGGTGGG',
#  'ATAATACTCATACGGA',
#  'ATGAAACTAAATGGGT',
#  'TATATAACAGGGCCAT',
#  'TGTAAATCTCAGCCAC',
#  'ACACTGCCACTGATAT',
#  'AAATGGATAACAACTT',
#  'ATTGCCAGTATCATCA',
#  'AATAATACTAGAGGGA',
#  'AAACGGTTCCACCCTT',
#  'ATCTCCCGTTATATTA',
#  'ATAATAACATTTGGTA',
#  'ATTGTTACTACAGCTT',
#  'TACAAATAGCACCAAT',
#  'AAAACAGGCAACTGTA',
#  'AGAAAAAAATTTTAAT',
#  'CCTGGATGCGGGGAAA',
#  'TTAGAAACTATGGAAA',
#  'TAGATGAGAGGCAGCA',
#  'CCATGCCACTTACCCA',
#  'AGACGCCTGACATTTA',
#  'GCATTTGATCCGGAAG',
#  'ACGACTCTGAGACTGG',
#  'AGTACCACTAGTAGAA',
#  'TGATGAAATGAATGAA',
#  'TCCTACTAGTAGCGAG',
#  'AGACAGTAGAAGGAGA',
#  'TTGGACTCTCTTTGTG',
#  'GAACACAACCCTAGAA',
#  'ACCGGCGGCGCCCAGC',
#  'CTCAAGTAAAGAAATA',
#  'TCTATTTGTATAAGAC',
#  'TCCCATCCTTTGTATA',
#  'CCAGCATGTTTGAAGA',
#  'GGATGGGGAGAAGAGG',
#  'CTATTACTAATTTCAC',
#  'TTAGCTCTCCCAGTAG',
#  'TAAGTACATCCTGACC',
#  'TAATGGTGGGAACTAC',
#  'GCATTGGACAAGCACT',
#  'AGCTGACGCCCGGCAA',
#  'TATTACACTAGCTGAA',
#  'CAGGGTAGATATACAA',
#  'TACTAGAGAGACAAAT',
#  'TAGCTACAATAATAAA',
#  'CCACTACTTAATCGAG',
#  'TAAACAGTACAGGGGA',
#  'TGGAATAAGACCTTGA',
#  'AAGAATATCCTTTGAG',
#  'AAGATTAATGCAAACA',
#  'AACCTTAACACGGATA',
#  'AGTTATCATGGGAGCT',
#  'CCGTGCAGTTTATTAT',
#  'ATCCCTCAGTTCTTTA',
#  'AGTAGTAATAGTGACA',
#  'TCCCCAGCCCGAGGGG',
#  'CTTTTAAAAAGGGAAA',
#  'CCGGCGCCTGTGAGTA',
#  'GTTGAGACTAGTATGG',
#  'TACCTCTGAACAGCCT',
#  'GGAGACCTTCAGGCCT',
#  'CCGGGAATATAACCGG',
#  'GATAGCTGTAAAAGAC',
#  'GATCTAATGGCAGTAG',
#  'GATAGCATCAGGGAAA',
#  'TGGACTGAAGAGAGGA',
#  'CTTTGCAATCAGACCT',
#  'GGGGGTAACAATGATC',
#  'AGAGTGGAGGAGACAG',
#  'GATAATGACAATTCTG',
#  'GCGAATGGTACTATCA',
#  'AACAAATCTAGTAATG',
#  'AGGACAATTAAAAAGT',
#  'TTTGGAGGCTTTATCG',
#  'CCACTAGTTTAGGACA',
#  'TCAACAATAACAGGAT',
#  'ACTCAGGAGAAATATA',
#  'AATTGGCAAATAGCTC',
#  'TGATGGGGAGAGCAAC',
#  'TAAAGGATATAACAAA',
#  'CATTGTGTTTCATTGT',
#  'CAATTTAACAGGATGA',
#  'AATAACAGCTCGAACA',
#  'GAAAGAGTATGCACTA',
#  'CCAGGCTAGTTTTTAC',
#  'ACGGTACTATTGATAA',
#  'AGAATGGACAACAGCA',
#  'ATAATGAATACAGATT',
#  'CAAGAACTAACAACTA',
#  'CATCTCAAACCCCACA',
#  'GCTACTATATCAATAG',
#  'TTGCACGAACTTAACT',
#  'ACAGCATATGCGTCAT',
#  'GGGGAAGATACAATCA',
#  'TTTCCATAATAACACA',
#  'AATAATGAAACAGCTA',
#  'AGAAGCACAAACGGAG',
#  'AAATCTCAAGACTAGC',
#  'TGACGTGGAAAGTATA',
#  'AAGAATCCAATTTTTG',
#  'GCATGTAACTCAACAG',
#  'GAATATCACTTTAAGA',
#  'AAGAAGGAGATGGAAA',
#  'CACGGATAGCGTGGAA',
#  'TACCCACCTCACCGAT',
#  'AGAGGTGGGTACTGAT',
#  'TACACACATAGGACCG',
#  'AATAGTACTAAATCAA',
#  'ATAACACTACAGGGAA',
#  'AGGATACCCAAGGATC',
#  'GAAAGAGTAAGAGGAG',
#  'TACTAATGAAAAGTTG',
#  'ATTCTATTTTTTCTCA',
#  'AATGGTACATCCAGCA',
#  'AAAACCGGCTGACGGG',
#  'CAAAAATGAAAGACAA',
#  'ACTACCCGCTATTGTA',
#  'CTCTAACAGAGCCTCG',
#  'CACGATAGGAAATATA',
#  'GATACAAGGTATAATA',
#  'AGGACTAATACTACTA',
#  'CCAATAGTACCCTCAG',
#  'CTATAAGCAGGGTGAG',
#  'ACTCCCCATAATCATT',
#  'ACTAAACAATTACAAG',
#  'CATCCATTAAAAAACA',
#  'AAGATATACACACCAA',
#  'ACCTGAGAATATTGAC',
#  'GGCGACCAACAGTCAT',
#  'AAAGAGATATTAGATT',
#  'ATGGCTACTACCTTAC',
#  'GTAATAATACTTTTAT',
#  'TTCTTAGCAATAATTG',
#  'CTGTAGATAAATAGTG',
#  'AGACTAATAGTACAGG',
#  'GAGGGGTTGGGAAGCT',
#  'AAATTACTACAACACT',
#  'AAATACAGTGGAGAGA',
#  'AAGAATAAGGCAAGGT',
#  'TGAGAAATCAAATCCC',
#  'ACAGAAGGGGTCTTCA',
#  'CCACCACTCAAGTTTT',
#  'CTCAATGAGTCTGTGG',
#  'AGCAGTTCCTAGGGAT',
#  'ACCGGCCGGGGGGAAG',
#  'GAGCTATTAGCCTGCT',
#  'AGAGCGTGCATATTTT',
#  'GTTGAAACTAAAATAA',
#  'AAAGTTAGGAAAAAAA',
#  'TTAATGGCACTATCAC',
#  'AAGAAATAGTCTATAT',
#  'TACACCCCTACCAACA',
#  'CAACACATTAACACAG',
#  'AGCATAGAATAAGGGA',
#  'AATGTAAGTATAATAT',
#  'TCGTTGCAGATACGAC',
#  'ACAACTCTGGACTCTG',
#  'AGGACTGAGAGCAACA',
#  'ACTAACGCAACGGAGA',
#  'CCAGTAGACATTAAGT',
#  'GTTACTAATTCCAATG',
#  'GAGCCAACTGGACTAG',
#  'GGAAACGGGACTAACA',
#  'AGAACAACTTGAGAAT',
#  'GGGTTGTAAATAATGG',
#  'TCAAGCAGTAATCCAA',
#  'GATATTGGGCTCCTAA',
#  'TGGAAAATGTGTCCGA',
#  'AATAGCATGAATGATA',
#  'CTGAAAGCAGGGTACT',
#  'ATAAAACAAGAAAAAA',
#  'CGATCTGACCCAAAAT',
#  'TTCATCAATCATCACA',
#  'TCCAGAAGAGAAGGCT',
#  'AGTAGCACTAGGGAAG',
#  'AACCATTATAGGGAAC',
#  'CCAATAAAATAGAGAG',
#  'AAACAATATCCTTTGA',
#  'GGAAAGGATGCAAATG',
#  'AGCGGGAACAAGAACG',
#  'TGGAAGTAAAAATAGC',
#  'ATTTTGTGCTTCAAAT',
#  'AAAGGTAACATCTGTG',
#  'CTAACGGACATACCAA',
#  'CCAGAGCAAGCCAAAT',
#  'CGACGCCGACGCAGCG',
#  'CATAGAAATGATGAAA',
#  'AGACCCATAGATGATA',
#  'CACTATCAGACTTCCA',
#  'TAGAAATTGGTACAGA',
#  'TGAGAATAACACAAAA',
#  'AGCTTAACCGCTTTTT',
#  'TACTGTGCCAAAGAAA',
#  'TTGGCAGAATGGTACT',
#  'CTCAGCTCCCCCAGTA',
#  'AGACTAACACTAACGA',
#  'GGATATCCTCTCAGTC',
#  'GGGAATTATGATGTTT',
#  'TAGAGAGATTAATTGA',
#  'CCAACAACGAGGAGAA',
#  'GGCATTTGGGGAGCCC',
#  'TCTTAATTGGCACTGT',
#  'TACCAAGCTTGATGCA',
#  'GATAAGGAAGGGGAAA',
#  'TCCTGAAGTAATATTA',
#  'GGACTACTACTAGTAC',
#  'CAGCACTGGGAATGCC',
#  'ACCAAAGACATACAAA',
#  'AAGGGCACACGGCAGA',
#  'AAGAATCTTGCTCCAG',
#  'TAATAAATGTAATGTC',
#  'AAGTCAAAGCCTCTTA',
#  'ATAAGTGAATCAGGGA',
#  'AAATGCCACACTCACA',
#  'TAATTAGCATTGGATT',
#  'TATAACTCTTAGAGTT',
#  'ATGTAATGGGATGGAA',
#  'TTTTGTTCCAGCAGAA',
#  'AATAGAACAGAGTCAG',
#  'TACACTTTTTAAAATA',
#  'TGGAAAAGGATAGCTA',
#  'TTAGGAATAAAACAAA',
#  'AATTGTAGTAAGGTTA',
#  'ACAGGTAATAGAACTG',
#  'CATGTATAATACAACT',
#  'TGGGGAGAAGGACAAC',
#  'GTTATAAATGAACTGT',
#  'GAAATACTATTTGCAG',
#  'GACAGAGGTGGGGGAA',
#  'TACAACAAACATAGTA',
#  'TGTTGGGTGCTGGAAT',
#  'CTAACAGAACACACAA',
#  'ACTCCAACCAGGCTGA',
#  'AAAACCTTTAAAAAAG',
#  'TGAATTAGGGAAGGTT',
#  'CGAGTGCAGCTATGGA',
#  'TTTTTTATCCAAGCCG',
#  'GGGGGGACATGTTACA',
#  'ATGGGGGACAACAAGA',
#  'ATCGTTTGCTTCCTCC',
#  'AGAAAACTAATCGATG',
#  'CAGTAGTAATGGCACC',
#  'CTAATGTGAATACTAC',
#  'TGCAATTCTTGTTATA',
#  'ATAATGATTACATCTG',
#  'AATGCAGGCAGAAGCA',
#  'TGTAAAGAAAAGGCAC',
#  'AGCAATGAGTCTGAAA',
#  'AAATAACATAGAGACA',
#  'TAATAGTATATATAAT',
#  'AGGTGGCCTCCTATAA',
#  'AAAGCGACAGAGAAAC',
#  'GTGAATGGAATATTAA',
#  'TGATTCAAATTCAAAC',
#  'AGAGCCGGAGGAGCTA',
#  'TGACCTCAGGGATGGA',
#  'GTGACAGAGATGGAGA',
#  'TCTAGAAATAAAGAAG',
#  'CCCTGGGAGGAGGACA',
#  'TGCCAAAGCTCCCTGG',
#  'GGAGCTATTAGAACTA',
#  'GGTCAATGACACCGGT',
#  'GCTCTGTAGTATCATT',
#  'ATGTCTCTAGTATAAT',
#  'AACCAAATAACACTAG',
#  'GAAAATCTCTAGCAGG',
#  'TGGAACTGGTACCTTT',
#  'GGGCAATAAGTGAACT',
#  'TCTTTTTAAAAGAAAA',
#  'AGAAGGAGGTTCCCTA',
#  'CAATAGTACTGCTGAT',
#  'AGCATAAATAAGACAA',
#  'CCCGTCTGGTCCCAGG',
#  'TCTAGACGCAGGACTG',
#  'AGGGAAAAATAAAAAA',
#  'TTAGTCCTGTGGGGGA',
#  'ACGGAAATCGTACCTT',
#  'ATATCACAGACGATGA',
#  'AGAAGTAACAAACTTC',
#  'CACTTCTAAATAAAAC',
#  'CCAATCAGTTGCTCCT',
#  'TGTAACCTACAACCTT',
#  'TACTAGTATGGAGATG',
#  'GTGGGGAAATTAGTGG',
#  'AAATTACTGGGACAAC',
#  'GGAAACACACTTTAAC',
#  'TTAAATAGCACAGGGG',
#  'CCACATAATAATAGTG',
#  'AGATCCACTGAAAACA',
#  'TTAACTTGTCCTAACA',
#  'AATGTTCCAATGTACC',
#  'AAACGTAAAGGGCGGT',
#  'ACATTAACCGCAATAA',
#  'GTAACAATACAGAGAC',
#  'AAAAGAAAACTTACTT',
#  'CACTTCTGACATAAGA',
#  'ACTCATACCTAATATA',
#  'GAATAAAACTCAAAAT',
#  'CATGCATGGCCTCTCC',
#  'AATAATACTACTAATA',
#  'TTCCAATGCAGCATCT',
#  'CAGAGTCAGATAACAC',
#  'GTAGGGAATACCAAAA',
#  'ACACCTAATAACACCA',
#  'ATGTCTAATAATTCAG',
#  'TAGAGCCGGAGGAGCT',
#  'TCAGGCGCCAGTGCTC',
#  'ATTAAACAAGTGCTAA',
#  'TGGGAAGGGCCAAAGC',
#  'GCACCCCGATGGGGGC',
#  'CAAGAAGTACAAAGCC',
#  'ATGAGAGAATGCCCTT',
#  'CATAGAAGCAGGTGTT',
#  'CAAACATAGGGAATAA',
#  'ACAGGACTCCTATGGA',
#  'TGATGATGATAATAAG',
#  'ATTAACAGGGCTAGCT',
#  'TAGTATGCTGTGTATC',
#  'GAAAGATTAAGACAAG',
#  'AAATAAATACTACCTA',
#  'TCCTCTTTTGGGTACA',
#  'AAGTAGGAACATTCGG',
#  'GATACCAGTTTTTATA',
#  'AGTGGAAAAAGACCAT',
#  'TAATAAGACTACAGTG',
#  'GCGAAGTTTATTTTGA',
#  'TGATATAATGCATGTA',
#  'ACCACCAGTGCCCCTA',
#  'AATAAGGCAAAGCTTA',
#  'AATGTAACTAAAGGAA',
#  'TCTTGACATGGGATGG',
#  'CTAACAATACTGCTAC',
#  'TAATGGAAATGACAGC',
#  'AGTGGAATGGGACAGA',
#  'AATGCAACTGGAACTG',
#  'GGGATGGTGATGGGAC',
#  'CAGGAGTGTGGTCCGG',
#  'AGGGATGGTACATTGA',
#  'GAAATAACATTTAAGC',
#  'GGCGCAAATAAGCCTC',
#  'GAACCAGACCAAGAAC',
#  'ATGTTAGATTCAGCAA',
#  'AATGTAAGTATAACCA',
#  'ATGCAATATTTACAGA',
#  'AGAATTGAAAATCAGG',
#  'AGGAAGATACTTAGAC',
#  'ACAAAGAATAATAATA',
#  'GAGGGGACTGGACAGG',
#  'ATGCCACCGACACAGA',
#  'CATCACCTGTGACAGG',
#  'CTAAGGAATTAGAGAA',
#  'TACAGACCCCGACCAG',
#  'GGAGCAGCAGGAAGGA',
#  'TGACAAATTGTAGTGG',
#  'AAATACAACAAGAAAA',
#  'AGTTTACTTTCCAGGA',
#  'CAGGCTAGAAGAGCAA',
#  'CCTCATTATACAACAC',
#  'TAAGAACCCTGGGCTG',
#  'AGGACGCAGAGAGAGA',
#  'TACTAACAGTTTTATT',
#  'AGAACAACAGGGAGCA',
#  'AATAATACTTGGATAA',
#  'AGCATAAAGACCATTG',
#  'GAGGATGGACGTAAAA',
#  'AAACGTGGAAGCGGAG',
#  'CAATAGCAGCCAGCAT',
#  'CAGGTAAACAAGACAA',
#  'GGATCAGAAGGGAACC',
#  'GGGTTAATTAGAAAAC',
#  'GCATAGAGTCAAATGT',
#  'TGAAGGAGAGCGCAAC',
#  'TCTTGGATAATAATAA',
#  'GTCAAGGAGTACTACT',
#  'CTGAGAGGAGGAGTGG',
#  'GCATTAAGGATCATCA',
#  'TAGGAATGGGAATTGG',
#  'ACTGTACTAACAACAT',
#  'GGCAAAAAATGACAAA',
#  'CCCCAAGGGATAAATG',
#  'CTAGTAGCACTAGTAC',
#  'ATGTATTTTGCACTGG',
#  'AGTAAGAGAAGGAATA',
#  'GTTAGCATAAAAGAAG',
#  'CCCTTTCAGCAGCAGA',
#  'GGGACCAGCAGCTCGC',
#  'AGTGGAGGGAGAAGTA',
#  'CCACTAATGGTACTAT',
#  'TAATACCACTAGTAGA',
#  'GAAGCCTTTTGCAGTG',
#  'TGTACTGGGATGCAGC',
#  'GCTCAACTTATACGTC',
#  'AAATTTCTATGTTTTA',
#  'CACCTAATAATTCAAA',
#  'CAGAGACAAATCCGCG',
#  'GGATAAGACAATAAGT',
#  'GAGATGGGATGGTGGA',
#  'CCAACCAGTCTCCCTG',
#  'AAGATAAGATGGAAGA',
#  'TGGGTACCTACAAGAT',
#  'TTTACAAGACCTGGAG',
#  'AATAATATAATACAAC',
#  'CTAATAAGAGCATGAA',
#  'GAAGAGCAGTTTATAC',
#  'CCGACTATCGAGACTG',
#  'CACCGAAACAGGAGCA',
#  'CCCCTAGGGCCAAATG',
#  'CAGCACTGTACTTTGT',
#  'CAGGTAAATTCAATGG',
#  'TAAAATGAAAGAAACA',
#  'ACCAGAGGGATGAAAA',
#  'AACGAATAATACTGTG',
#  'GATTTCGCAAATGCAG',
#  'GGAGCAATAAAACAAA',
#  'ATAACAAGATAAAACA',
#  'ATGAAGCAATGAGGCA',
#  'AGCAGACGTCACTTTA',
#  'AACCCAGAAGAGGTAG',
#  'GCTATAATACAACTCT',
#  'CTACTGCCACTGGCAC',
#  'GGGAATCTCACATTGT',
#  'AGGATAGGAAGCAACA',
#  'GAGGAACTCCTCGAGT',
#  'AGGAAGCAATAAGCTG',
#  'GACACGAATAAGAATG',
#  'GCCACCGTCGCCGGAC',
#  'CACGTGGACCAATTAC',
#  'TAAGAATAGGACCAAT',
#  'ATGGGTTGTCATATAT',
#  'ACCTGCGGTTCCTCAT',
#  'AGGGAAAAAAATAAAA',
#  'TCAGAAAATAGCACAG',
#  'AGGGAAGGGGAATTAT',
#  'CACTGACCGTACAGGC',
#  'TTGAATGGGGGGATAA',
#  'GTAATAGCAAAGTAGA',
#  'ATACAGTAATGTTACC',
#  'CAGAAAAATGATAATT',
#  'ATTTAGGAATAATACA',
#  'CATGCAGAATAAAACA',
#  'GAAGATGGATACATAT',
#  'ACACGGAGAAGCCTTA',
#  'GATGCAGATAAGCCGC',
#  'ATGCAGTACAGGAATC',
#  'GCCTTGTTGGTTTTGT',
#  'AAATTAAAACAGAGTG',
#  'TAACGCTACGGCTAGA',
#  'GGATACTTGCACAGCA',
#  'GGCTACAGCACAATAA',
#  'GCAAAATCAGCACCTC',
#  'CCGCCCTTGGGGAAAA',
#  'TGGGGAAGAATGATAC',
#  'TAAAAGGGGAGCCGAG',
#  'TTTAAATATATGGGCA',
#  'TATGGGGGGTATTATA',
#  'GTTTATTGGATCACAG',
#  'TTTCATTGTCCCCGGT',
#  'GGATGGCCTCGTGGAA',
#  'GATTATCAGGTGTAGA',
#  'CAAGAGGAAAAGGAAC',
#  'GGATTTCGCATTACTG',
#  'GAATTAATCCACTGGT',
#  'AAATGGCAGTGTGCAT',
#  'GGTTGAGTTGGGGCAT',
#  'GTACTCGAGCACCGCT',
#  'AGGGACAGCTATATCC',
#  'ACCCAGAATGTCAACA',
#  'AGTCGTGATGCCACCA',
#  'ATAAAAGTAAACAAGT',
#  'CTTGATGGGGAGAATA',
#  'AGAAGAAAAATTCAAT',
#  'CAGCAAGGGCTATGGG',
#  'GCAACTCTAGGAAAGG',
#  'ATACAAAAATGCTTTT',
#  'CTAAAAAAACTTGGGG',
#  'TGCTTTCAGCACAAGG',
#  'AATGTGTTTACCAAGG',
#  'TAAATGGTGTATACAT',
#  'TTTTTAGAAAAGGTAG',
#  'TGCATATGAGAAAGAA',
#  'AGACACAATAGATGAG',
#  'AGAAAATAAAAGAACA',
#  'AAAATGTCACAAATGG',
#  'GGCAAGCAGGGAGGTA',
#  'CTTAAGAAGGGGGTTC',
#  'GTTACTAACATCACTG',
#  'CCTCCAATAATCCTTT',
#  'AGATAAATTAAGAAAA',
#  'TTTGGAGGGATGGGTG',
#  'GAAAGCATCTGCTGAG',
#  'AAGTAGCCAATGCTGT',
#  'ATGATTCCAGGCCAAA',
#  'ATGACAAACTTAGAAG',
#  'AAAGGAGGAATTAAAG',
#  'AATAATAATAACAGTG',
#  'TACAGCAGAGGTAACA',
#  'CAATACGATTTGCATA',
#  'ACAAAACAATCATTTT',
#  'CAATGTGAGAGAACAA',
#  'AAAAAAATTTAACATG',
#  'TCTTGACATGGGATGG',
#  'TCAAACAGCAGAGAGA',
#  'GGTAATGATACCTGTA',
#  'ATATGATAGTAAAATG',
#  'GAGATAATTTGTGGGT',
#  'AAACACTCCACCTTCA',
#  'AGTAAACAAAATTGGA',
#  'GAAAATGGACCAAACA',
#  'GGATGGGGGAACCGGG',
#  'TGTGCCAATGATACCA',
#  'CCACTAACACAAATAT',
#  'AATCAAACAGCATGGA',
#  'TCCTCAAGACGAGACC',
#  'CACTACTGGCAATGAA',
#  'GAGGGAGACAGCAGCA',
#  'GTAACAAATGGCGCAA',
#  'ACAGGATTGGTAAGGC',
#  'GCACGCTTGTACTGGG',
#  'ATTGCTAGTTTGCTTT',
#  'TTGAACAGCACGGAAG',
#  'GGAGTAAGAACGATGT',
#  'AGGCAGGGAAAAGCGG',
#  'GAGAAGGAATGAAAAA',
#  'GGTATCACTGAAGGAG',
#  'ATTAGCACTAACCATA',
#  'AATTGTACTGGGGGGA',
#  'GGAAGGCATCACGACT',
#  'ATTATACCCAGAACCC',
#  'AGGGACAGAGATCTTC',
#  'GTGATATTAACAAAAA',
#  'GCCCCTGCAGCTCGAC',
#  'TGATACAGAAACATTC',
#  'CTGATAGTAATGAGCT',
#  'AGAAAGTAGTGTGGAT',
#  'AGGACGAAATGGAGAG',
#  'ACCAGTCGCAATAAAT',
#  'TGGTGTTCAGCTATGT',
#  'AAAATTAGGAGAACGC',
#  'TCAAAATAATACTGAT',
#  'TAAGGTCAAAAAAGAA',
#  'GATAAGAGGCAAAAGG',
#  'ATAACACCATGAAGGG',
#  'CACAGAAATGGTTTAG',
#  'AGAAAATAATGGAACA',
#  'TTACAGGCAATTATAA',
#  'TTCCAGGATGTCACCC',
#  'TAACAATACCGGTAAT',
#  'GGGATCGCTGAAGGAG',
#  'CTATGACCCCAGAAAA',
#  'TCAGTGAAGGCAATTG',
#  'AAGGGAATGGTTCAAT',
#  'TGTTTTGTAATGCAAA',
#  'AGCATCAGCAGAAACA',
#  'ATAAATGTCAACTTAA',
#  'AAAATAGTGTAGATGG',
#  'GGGAAGTAAGCCCACA',
#  'CTAGGATGGAGGGAAA',
#  'AAGTAATAAGAGCTGA',
#  'GTAAAACAAACCAGAA',
#  'TGCACTTGGAATGACT',
#  'GGCCCTACAAAACTAT',
#  'AGGACACTATAGCGAA',
#  'GATACAGAACGTAACG',
#  'AATGCCCCTGGGTGGT',
#  'AATAATACCAAATATA',
#  'TAAATAAAACTGGAGA',
#  'AGAGGAAGAGTCAGAG',
#  'CTCAAAGAAAGCAGGA',
#  'GGTGAGAGGAACAATA',
#  'CTGTAGGTGAAGAAAT',
#  'AAAATTAACTGAAACA',
#  'ACAACCAAGTTTTAAA',
#  'CATGTGGAAGTGAGTA',
#  'AGGAAACACTCCACAA',
#  'TTTAAACAAAAAGAGG',
#  'CAGCACCGTATGCCCC',
#  'AAGTAACCCATCTGTA',
#  'TGGCCTGAAGGGTCAG',
#  'CAGACCAAGCAGTAGC',
#  'AGTAATAATAGTACCT',
#  'AAGAAAGTAGAAGGAG',
#  'TCATATACAACAATTA',
#  'GCAGGAGCAGGGGGAC',
#  'TTATTAGGATACAACA',
#  'AGTAGCAGAATTGCAA',
#  'AAAACTACAGAAGGAA',
#  'CAAGGCAAAGGACATC',
#  'TAAGAAAAAAAATCCA',
#  'ATAGTAATGATACCTG',
#  'GGAAAGCATTTTTAGC',
#  'TTTTGATGCTAAAACA',
#  'ATGCCAACACCACCAC',
#  'GATTCTAGCAATAATG',
#  'AGTAATGGTCCGCTCA',
#  'TTGACTCAGCCTGGCT',
#  'GGCTACCTGAAGTGAG',
#  'AGAAAATTACTATACT',
#  'CAGAAGGTGAAAGGAG',
#  'TACCAATGTTACTAAT',
#  'TTACTACAGGGCTATT',
#  'TGGCGCCCAACCAGGG',
#  'GGCTTTTTTCTTAACA',
#  'AATGAAAATAAGAAGA',
#  'TTTGGGGGCCTCCAAA',
#  'AGAGAAGAATGGGACA',
#  'AGAAAATCACTGTCAG',
#  'ACTACAAATGTTACTC',
#  'AGAGAATTGTGATAAA',
#  'CAGCGCTCGTGGGGAT',
#  'GAACTAATGCAAAGGA',
#  'GCCAACAATAGCAGTG',
#  'GGAAAAACCGGTCAGA',
#  'CACGCCAACCAAATCG',
#  'AAGCCAAAGTATCTGG',
#  'GGGATAACAATGATCT',
#  'CAGCTATAAACAATGG',
#  'CAAGTGCAACAAATGG',
#  'TGGGCAGTATGGGCAG',
#  'AAATGATGGAAAAATG',
#  'GCAAATTTTAAAAAAA',
#  'TAAGAACAACAGCAAC',
#  'ATGAGACGTACTGATC',
#  'TAGATCAAAGAATACA',
#  'GCGGCATCACTAGAAG',
#  'GGAAGTGTCTGCGCTT',
#  'GAAGTATAACCTTCGG',
#  'CAAATAAGAATTGGAT',
#  'AATGGATGCTTAGCAA',
#  'CAATTGCAATAATGAA',
#  'TGGAAGCGACGGTCTG',
#  'GAAGGCTGAATGGATT',
#  'GACAGTAGAGATCCAG',
#  'TACAATGGCCCCTACC',
#  'TAAGAAAACGCCCATT',
#  'ACAGGAAAAAAGGTTA',
#  'ACAATATAAATTGAAG',
#  'CACCCACTCCCCAGCA',
#  'AAAAAATTTAATAACA',
#  'AATGGATATGGACCAT',
#  'GGGGATACGGAGGAGC',
#  'AGAGAAAAAATATACA',
#  'GTGCAGCTCAATGGAA',
#  'GTAAGGTTAAGGCAAA',
#  'TGATAGCAACAGTACT',
#  'GCCTGTTGATGTGGTT',
#  'TACAATAGTCCAGAAG',
#  'GTCCAAAGGTCACCTT',
#  'TACTTTAGATTGTGCC',
#  'AAAATAGCTGTGACCT',
#  'CGGCGTGGCCCGGGTG',
#  'TAACGAAGTCAAAAAC',
#  'CCATATTCAGATTTCA',
#  'TATAAACATTGCATCA',
#  'ACAAAATTGGGCCAGA',
#  'GCAATGCCAGGAATCA',
#  'GCACTAATCCTCATGC',
#  'GAAGAGCAATGGAATT',
#  'GCTTGCACAAGCGGCG',
#  'TATACTACAGTTTAAT',
#  'TCATTTGTATGTCTCA',
#  'ATGATACAACTGAAAC',
#  'CACCGCTGAAATGAGA',
#  'CACGGACACGGAGATC',
#  'AAGCAATTTTACTAGA',
#  'TATAAGTTGTTAAGAT',
#  'AACCTAACATACATTT',
#  'AGTGGTAATGCTACTA',
#  'TGCAGAATGGGGCTAG',
#  'ATTTGACAATTAATGC',
#  'GGGGGTAATACTACAG',
#  'TAACATGACTAAAAAC',
#  'AATACCTACCAAAATG',
#  'AGAGAATTCTCCTTGA',
#  'GCTAAGAGGGGAGGCC',
#  'AAAAAAGAATATTCAT',
#  'AATGCTACCCACCTCA',
#  'TCAGATTCAAGTACAC',
#  'TAAAAAGAAACGGCAT',
#  'TGATCTCAGGGGGAAC',
#  'ACAAGCAGTGGGGACA',
#  'TATAATAGAAGGAAAA',
#  'ACAAATAACCATAATA',
#  'TGAGAGAAAACCTGCT',
#  'GGGAGCTGTAACAATG',
#  'TAAGACCAAACCTAAT',
#  'TAGCAATGAAAATATC',
#  'CTTTGGAACGAAGGGC',
#  'CTAATGCTACAGCAAA',
#  'TACTACATGGGAAAGG',
#  'TTATACCAGGAATCCT',
#  'ACCACTATTGGTCAGG',
#  'CAGTGCACCTATCTTG',
#  'ACTGGCTTCATAGAAC',
#  'CTTTACCCTGCACTGT',
#  'CCGGCCATATGAGAGA',
#  'TTGTAATACCTCCATC',
#  'ACCTTGCACGAGGTGG',
#  'AGCAATAACGCTAGGA',
#  'GTACTCTTGACAACAG',
#  'ACCTCTAGCCCCTTTA',
#  'GTTATATTGTCACCCC',
#  'TTTAGCAGAAGAAAGT',
#  'TAGGAGAGGAGACCAA',
#  'TAGCGCCTGGCTGCTT',
#  'AAAGCCAATATCTAGG',
#  'AAAGTTACACCCCACT',
#  'CACTGATTTGAAGGAG',
#  'TGTTCAAAAAAGAAAG',
#  'TAACAACACAGAAAAC',
#  'ATTTTGGAAACTCCTT',
#  'CCTCCTGTGGCCGCTT',
#  'CTATCAGATTTCCATG',
#  'AGGCAGAAGCGAAATA',
#  'GCAGTATCAATAGTAG',
#  'GCCACGAATAATAATG',
#  'TAGAAATAATAGTGAT',
#  'ACCTGCTCCTGTTTCC',
#  'AATTAAAGAAAACAAT',
#  'AAAAAAAATAGTGGGA',
#  'AACCAAGCAGTACCAA',
#  'TATAATTTACTTACGG',
#  'AAAGTGTAAGGACACA',
#  'CAACAGCCGCACAAAT',
#  'GCACTCAAAAATCCAA',
#  'TCTATTTTGCGCATCT',
#  'CTCCACTAAGAGCTAT',
#  'TACTAGTGACAACGGT',
#  'GTGTTCCTACAGCAGC',
#  'TAATACTAATAGTAGA',
#  'TGTGAAAGAATTGGCT',
#  'GACTTGTTCACTGGAT',
#  'ATGTGTTCATCAAATA',
#  'GCCACAGGGGATAATG',
#  'CTCCAGTTTTGTTCTT',
#  'CACAGACAATAATGGC',
#  'TACTAATAAGGTGGAG',
#  'AACTTTAATCATTATT',
#  'CGGGCTACAAGGGCGT',
#  'AAAGAATTACACAGCC',
#  'GACAGGGAATGATACT',
#  'ACACGAGGCGCCAGGA',
#  'TGTACGTGCAGAGATA',
#  'TAGAGTCAAGTAGAAC',
#  'GAGACAGGAGCTGAAA',
#  'CGCCACGAATAGCACT',
#  'CTTGAGATTTCGCAAA',
#  'GCTCTTGACCACAGCT',
#  'TTACTAGCGATAATAT',
#  'AATTTAGTATCCAATA',
#  'AGAATAGGAGAGAGAA',
#  'AAATAAAGGAACACAA',
#  'TAACAGCCTTAATGAA',
#  'CAGAGGGAGCCATACA',
#  'TATGCACCCAATACTA',
#  'TCACTATACATAATAA',
#  'TAGGTGGCTACACAAT',
#  'GAGCCAGCACCAGAGC',
#  'TACAGAATAAAACTCA',
#  'GCAAAAGAAAGTTAGG',
#  'AAAAAGGAAGCACCTG',
#  'GTTACTGATAACAGTA',
#  'CTGCCAGCATAATGGA',
#  'AGAAAACAGGAAAGTT',
#  'AAGACTAAGAAGAGCT',
#  'GGGTCAAAACCGGGCG',
#  'TAGTGATATTAGTTAT',
#  'GATATATTAAATCAAA',
#  'CAGGGGGGCAATAGAT',
#  'TCCAGCAATGCTGCCT',
#  'CTCCCACTAATGCTAC',
#  'ATGAAAAACCTCAATG',
#  'GAAGTATCTGTAATGT',
#  'CAGCTGATAGGAACAC',
#  'CAAATAACATTTCAGG',
#  'GAAGGAAGCAACAAAA',
#  'TGTCCAAATGTCACCT',
#  'GGGCCCGACTCTCAAC',
#  'CTAGGACAGAGGGGGT',
#  'AAATTGTTCTTTCCAT',
#  'AACAGCAAATGAAACA',
#  'AAAATCTTATTTCCAT',
#  'AGGGGGATACAGGAGA',
#  'TGGTAGTACCCACAAT',
#  'CTACTTCAAGCAGTGA',
#  'AGACTAGAGAAGCAGC',
#  'TACAAAACTATGAGAC',
#  'CTCGATGCAGGAAAAG',
#  'GTAGTACTCTTAATAT',
#  'AGGAAAAATTATCAAG',
#  'AATGCCACTTACCCAG',
#  'AATACACATAGCTCGA',
#  'TACGGATGGGAGTCAA',
#  'ATAAATGAAACCATGG',
#  'TCTTAATGACACCAAT',
#  'CACACAACCCACGAGA',
#  'GAGAGGCCCTCCCACC',
#  'AATAATTCAACAATCA',
#  'GCCACATTCAGGGGGA',
#  'GACCTGGGCGGGGAAG',
#  'ACAAGACTAATGCCAC',
#  'TGATACAATTGATGTT',
#  'AAATTATATATTGAGA',
#  'CAATAATGCAAACAAT',
#  'ATTCATCAAAAAATGC',
#  'AGTAGCTATTCAGAAC',
#  'TGGATTGAGAATAAGA',
#  'TACAGCTTTTAGAAGA',
#  'AGAATAGTGAGGATAG',
#  'AACAGCCTATTACATC',
#  'ATTGGGAATCCTGTGG',
#  'CAAATGAAACAGACCT',
#  'ATAAATCAATAAGGAT',
#  'CTAGCGATAATAGTAG',
#  'ACACAATATATGTGCA',
#  'ACCAGAACAACAACAT',
#  'TTTGGCTCTGTGATGG',
#  'ACTAATGCTCCTGCTG',
#  'GAGGACCATGTACAAA',
#  'CCAGCAACAGAGGATC',
#  'AATGTAACTGAAGGAA',
#  'ATCAACAAACTTAGAG',
#  'TATCACTGTAAACTGT',
#  'AGAGGGAGACAGCAGC',
#  'CCGTAGGAGGGGACCT',
#  'GCAGGTTTAATTATAC',
#  'GGCAGACAGCATATGC',
#  'TAAGTATAAAAAAGTA',
#  'ACAGGAAAACACAGCC',
#  'GGTGGAAAGGTATCTA',
#  'GGTTAGATGGCATGGA',
#  'TAAGGGTACGCTTTGG',
#  'GCTCCACGGAGAAAAT',
#  'AGGACTGAGAATGATA',
#  'AGGGGGGGAGTAGTAA',
#  'ATCAAATAAATTAACA',
#  'TACCAGCTATATGATA',
#  'GGATGATACTACTTGT',
#  'AATTTTAAAAAATGTA',
#  'ATGGCTTCTTAGCTCT',
#  'GAACGTATTAGGATTT',
#  'ACCACTAGCACTCCTA',
#  'CCCAAAAAACTTCAGA',
#  'TTAATAGTGCATGGAA',
#  'ACACAAATAACCCTAG',
#  'GTAATGGAGAATCTCT',
#  'ATGATAAGCTTCTTAG',
#  'GCACTAATAAGAATAA',
#  'ACGCTGCTTCGGTCAA',
#  'ATGTTAGAATGGGGAA',
#  'GGGGTCTCTATAGAAT',
#  'AATATGTGTTCATCAA',
#  'AAGACAATTCACTCTC',
#  'AGGAATTAATCAAAGA',
#  'GCTTCATGCATATGGG',
#  'TTTAAAGGTAGTATCA',
#  'AAACCATTAATTATAG',
#  'AAACACGACAGAGGTA',
#  'AAGAATAGTAGTCATA',
#  'GAAAGAAACGAGGGAA',
#  'CTATGGCGCGCTGGAG',
#  'CATAGAAGAAAAAGAG',
#  'TAATGAGTCAGCAGGT',
#  'GGGGATGCGAATTTTA',
#  'TAATAACACTACAGGG',
#  'AGGCCGTCAGGACCGA',
#  'TTCCTATTAGACATAT',
#  'GGAAATGGCAACATAG',
#  'TGGGGAAATATGGACA',
#  'TACATTCAATGAGTGG',
#  'ATGAAGAATGAAATGA',
#  'ATTAATAGAAACTTGT',
#  'TAAGAGATGGAGTGAG',
#  'GTTCAAATACCCCCTT',
#  'GGAGATTTTAAAAAAG',
#  'GGAAGTGATATTCAGT',
#  'CCTGAGAATGTTGACA',
#  'AGTGTGCAAAGTGCCA',
#  'ATACTACTGCCACTAG',
#  'CTGGATGGGAATGATA',
#  'TAATGGCAATAATACT',
#  'GGAAGGAAAGAAGAAC',
#  'ATTATGGTCGACAATA',
#  'CAACTATTAATGCTAT',
#  'AGATAAAATTAACATG',
#  'TGCTAATGTAACTTTA',
#  'AAAAACTAGGACAACA',
#  'CTGCCGCAAATGTCAG',
#  'GTGACAATGAGAACAA',
#  'ATAATCATTAGGTCCA',
#  'AAGCAGGGGGGCAATA',
#  'CCCAGAATCCCATGGA',
#  'CGCGGGAGGAGACCCA',
#  'ACCATTAGTAACATTA',
#  'ATACCAGCAGGAGAGA',
#  'CTCAAGATGATGGGGA',
#  'CTCAACTACCTGTTAA',
#  'GAGTAAATAGTAGTGA',
#  'TTAACACAGCAGGATT',
#  'ATAACCTAAAAGGCCT',
#  'AACAGCTCTGAGGATG',
#  'GTTGAATGGTACTAAA',
#  'TGTCAAAAATGAAAAG',
#  'TGGGAGTAAATAAGCC',
#  'TGCTGTTAATACCAGT',
#  'TTCGGACAGCAATCAG',
#  'GAAGAATGATACGAGT',
#  'TGGAAGCATTCCCCTC',
#  'GTGAATCTCAGAGTTT',
#  'CACTTTCCTGATAGAA',
#  'CAAGGAAAAATTATCA',
#  'CAAATGTTACTGCCAA',
#  'AGCGAGGATATAATGG',
#  'AGATGTCAGTACAGTA',
#  'AATGCAAATGCAACGG',
#  'ATAAAGCTTCACCGCA',
#  'CGGCGATCAGGAGCAT',
#  'GTTAATATTACTAATA',
#  'CCCCGCCAGGCCCGAA',
#  'AGATAGTAGCGAGAGA',
#  'TTGAATGCTACAGACA',
#  'GATAGTTCCAATGGAT',
#  'CATTCGAGGCTTGCCG',
#  'GAAAGTAGGCAAAATT',
#  'TACTGCTGCAAATGGT',
#  'GTTTAATAGAAAAGGA',
#  'ATGGTCAAAGATGAGG',
#  'ATAACCCATATACCTG',
#  'GAGGAGTGGTAGCCGT',
#  'GCATCATATGCCGCTG',
#  'TGGTTGGAAGAATTCC',
#  'CGGCCTCAAAAGGGGG',
#  'ACCACAGCAAATAAGA',
#  'GGGTGGAACATGGGGC',
#  'CCAAGTTAGAAAAAAG',
#  'AAATGATACTTGGAGT',
#  'ACAGTACTAATGACCA',
#  'ACAGGAACAGGGAACC',
#  'GGAATGAGGGAAATGA',
#  'AAACATTTTGAAGAAA',
#  'ATAGTTGTGTACACCT',
#  'TAACACCACCGGCTGG',
#  'AGAATATTACTGACGA',
#  'AAGTCAGAGTGAAAAA',
#  'AATAACACCAAGTAAG',
#  'AATAAAACTATAATGT',
#  'GTGGGGGTAGGGATAA',
#  'AGTACAACATCAGAAA',
#  'AGCACAGCACATACCA',
#  'ATACAGGAAATAATAA',
#  'GGCAATGATGAAACAA',
#  'GTCACAGATGAGGACC',
#  'TATACAGAATAATGGA',
#  'GTATGACACCAAGGAC',
#  'AGGAGCAATGGAGGGA',
#  'GGGAGAATGCCCTAAA',
#  'AAATGGCACTACCAAT',
#  'GTACTATCACTTAAAA',
#  'GCTTAATGCACCTGTA',
#  'GACTTGGAATGAGCCC',
#  'ATGACAATGAGTCTGA',
#  'TGCTTTTTAAACAAGG',
#  'AATGACACAGCATTAA',
#  'CCACTTTCAATAATAC',
#  'AGGAATCGCAGTTCCA',
#  'CACCACCACAAGAAGA',
#  'GAGGAAAATTTAATAG',
#  'ACTACTAATGTCACTG',
#  'TACCATAAATAATGCC',
#  'GTGAGGGAGGGAACGG',
#  'AGAAAATCGTGTCACT',
#  'CATAAAAAAGAAGAGT',
#  'CATTTTAATATCATTG',
#  'ATTAATATTAATAACC',
#  'CTACAAGATCTACAAT',
#  'GATAGCCCGCACGATT',
#  'CTCCAGGCAGTGAGAC',
#  'GCGGGGAAAGAAAATT',
#  'GAAGCAAGAAGAAATA',
#  'TCGGAGAACAGGGAGG',
#  'GATCAGATAGTAGTGA',
#  'AAGACTAGTAATGCTA',
#  'ATACTAAAAGGCCAGA',
#  'CATGGGGGCAAATAAT',
#  'ACCTTGGGAAATGAAA',
#  'TACTACTTCTAGCTGT',
#  'AGGTAAGAAACAATTG',
#  'GGAAATGTCCTGCTGT',
#  'TGTAGAAAATAGAACG',
#  'GAAAGTATTAATGAAA',
#  'AGGACCAGGGAAGCAG',
#  'TAATATGAATTGTACC',
#  'TGCTGACACAGATGGA',
#  'TATAACTGGACTGGGT',
#  'TTAAGTAACCAATGTT',
#  'GGTCAAAGCATAGTCA',
#  'AGAGACAGGGAGAATA',
#  'ACTTGGCCCGCTGGGG',
#  ...]

# %%
infilename
# Out:
# 'out.csv'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42424\33968229.py in <module>
# ----> 1 abcdef = pd.read("out.csv")
#
# AttributeError: module 'pandas' has no attribute 'read'

# %% [markdown]
# ## check performance

# %%
covid_check = pd.read_csv("COVID_predictions.csv")
hiv_check = pd.read_csv("HIV_predictions.csv")

# %%
covid_check
# Out:
#       Unnamed: 0                                           id  Position  \
# 0              0      Delta|hCoV-19/England/QEUH-20A8462/2021     10960
# 1              1      Delta|hCoV-19/England/MILK-2CE551F/2021      1696
# 2              2     Iota|hCoV-19/USA/RI-CDC-QDX24520530/2021      6032
# 3              3           Beta|hCoV-19/Turkey/HSGM-7845/2021     29696
# 4              4       Alpha|hCoV-19/England/ALDP-EE9E8D/2021     25152
# ...          ...                                          ...       ...
# 6604        6604       Iota|hCoV-19/USA/NY-CDC-LC0023793/2021     28336
# 6605        6605       Epsilon|hCoV-19/USA/CA-CDPH-UC578/2021     23856
# 6606        6606          Eta|hCoV-19/Canada/ABPHL-12092/2021      5744
# 6607        6607        Eta|hCoV-19/England/HSLL-155A782/2021     27360
# 6608        6608  Delta|hCoV-19/USA/FL-CDC-STM-000614512/2021     11840
#
#       Maskpos Original_Sequence Predicted_Sequence Target_nu Predicted_nu  \
# 0          11  ACCACTGGTTATTACT   CCTTCCCTTACGGGGA         A            C
# 1          10  TGAAAGGTTCGGATTA   CCTTCCCTTCAGTAGG         C            C
# 2          15  AATTTGCTGATGATCT   TCTCCGTCCTAAAAAA         C            A
# 3           8  TGTGGAAAGATCGACC   CCTTCCCTTATGGTGG         A            T
# 4           6  TTTTACAGCTGGCTTG   CCTTCCCTAATTTTTT         C            C
# ...       ...               ...                ...       ...          ...
# 6604        8  AATTAACGCCAATAGC   CCTTCCCTTATGGTGG         G            T
# 6605        6  GTGCTCTAACTGGAAT   CCTTCCCTAATTTTTT         C            C
# 6606       11  TAAAGAAACTCTGTAT   CCTTCCCTTACGGGGA         C            C
# 6607        6  GCTACGTGTGAGCTTT   CCTTCCCTAATTTTTT         G            C
# 6608       12  GCCACTGTACATTCTA   CCTTCTCCTTCAAAGG         T            A
#
#       correct
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ...       ...
# 6604        0
# 6605        1
# 6606        1
# 6607        0
# 6608        0
#
# [6609 rows x 9 columns]

# %%
hiv_check
# Out:
#         Unnamed: 0        id  Position  Maskpos Original_Sequence  \
# 0                0  MK115290      9072       13  CAGTTGGACCCCCAAA
# 1                1  AF286238        16       12  TCGAAGCGAAGTACCA
# 2                2  JQ316127      1584        5  GTATTGCCCTATCAGC
# 3                3  MK303350      5952       12  CAAGCACAAATGATAG
# 4                4  MH897917      6752       11  CGATTTCCGGATAAAA
# ...            ...       ...       ...      ...               ...
# 155533      155533  MF373131      6880        8  GACAATAGGAGAAATA
# 155534      155534  MH897912      6016        2  CAATTCGACCGAGTCG
# 155535      155535  MF373175      5360        3  AAAATAGGAAACTGTT
# 155536      155536  FJ388910      1136        1  AGGGGGGCAATAAGAA
# 155537      155537  JN692473      7168        5  CGGTAGTGAAATCTTC
#
#        Predicted_Sequence Target_nu Predicted_nu  correct
# 0        CAGTTGGACCCCAAAA         C            A        0
# 1        TCGAAGCGAAGCACCA         T            C        0
# 2        GTATTGCCCTATCAGC         T            T        1
# 3        CAAGCACAAATTATAG         G            T        0
# 4        CGATTTCCGGATAAAA         A            A        1
# ...                   ...       ...          ...      ...
# 155533   GACAATAGGAGAAATA         G            G        1
# 155534   CTATTCGACCGAGTCG         A            T        0
# 155535   AAAATAGGAAACTGTT         A            A        1
# 155536   TGGGGGGCAATAAGAA         A            T        0
# 155537   CGGTGGTGAAATCTTC         A            G        0
#
# [155538 rows x 9 columns]

# %%
covid_check[['Maskpos','correct']].value_counts().sort_index()
# Out:
# Maskpos  correct
# 1        0          314
#          1           97
# 2        0          283
#          1          128
# 3        0          283
#          1          128
# 4        0          283
#          1          128
# 5        0          314
#          1           97
# 6        0          314
#          1           97
# 7        0          314
#          1           97
# 8        0          284
#          1          129
# 9        0          284
#          1          129
# 10       0          316
#          1           97
# 11       0          316
#          1           97
# 12       0          332
#          1           82
# 13       0          332
#          1           82
# 14       0          332
#          1           83
# 15       0          334
#          1           84
# 16       0          314
#          1          105
# Name: count, dtype: int64

# %%
# Reshape with pivot_table() for a pivot table structure
pivot_table = pd.pivot_table(df, values='Value', index='Category', columns='Subcategory', aggfunc='sum')
print("\nPivot Table:\n", pivot_table)

# Handle missing values (optional)
pivot_table_filled = pd.pivot_table(df, values='Value', index='Category', columns='Subcategory', aggfunc='sum', fill_value=0)
print("\nPivot Table with Filled Values:\n", pivot_table_filled)

# Multiple aggregation functions
pivot_table_multi = pd.pivot_table(df, values='Value', index='Category', columns='Subcategory', aggfunc=[np.sum, np.mean])
print("\nPivot Table with Multiple Aggregation:\n", pivot_table_multi)

# %%
grouped_COVID = covid_check.groupby(['id', 'Position', 'Target_nu', 'Predicted_nu'])['correct'].count().reset_index()
grouped_COVID
# Out:
#                                                    id  Position Target_nu  \
# 0     Alpha|hCoV-19/Belgium/Jessa_11-2119-002221/2021     21536         A
# 1     Alpha|hCoV-19/Belgium/Jessa_11-2119-002221/2021     21536         A
# 2     Alpha|hCoV-19/Belgium/Jessa_11-2119-002221/2021     21536         A
# 3     Alpha|hCoV-19/Belgium/Jessa_11-2119-002221/2021     21536         A
# 4     Alpha|hCoV-19/Bulgaria/21BG-EU_002140_Pl20/2021        16         C
# ...                                               ...       ...       ...
# 1658        Zeta|hCoV-19/USA/CO-CDC-ASC210029043/2021      6064         G
# 1659          Zeta|hCoV-19/USA/WA-UW-21041469819/2021      2160         G
# 1660          Zeta|hCoV-19/USA/WA-UW-21041469819/2021      2160         G
# 1661          Zeta|hCoV-19/USA/WA-UW-21041469819/2021      2160         G
# 1662          Zeta|hCoV-19/USA/WA-UW-21041469819/2021      2160         G
#
#      Predicted_nu  correct
# 0               A        4
# 1               C        6
# 2               G        1
# 3               T        5
# 4               A        4
# ...           ...      ...
# 1658            T        5
# 1659            A        4
# 1660            C        6
# 1661            G        1
# 1662            T        5
#
# [1663 rows x 5 columns]

# %%
# Reshape with pivot_table() for a pivot table structure
pivot_table = pd.pivot_table(grouped_COVID, values='correct', index=['id','Position','Target_nu'], columns='Predicted_nu', aggfunc='sum').reset_index()
print("\nPivot Table:\n", pivot_table)
# Out:
# Pivot Table:
#  Predicted_nu                                               id  Position  \
# 0             Alpha|hCoV-19/Belgium/Jessa_11-2119-002221/2021     21536
# 1             Alpha|hCoV-19/Bulgaria/21BG-EU_002140_Pl20/2021        16
# 2             Alpha|hCoV-19/Canada/QC-1nDJXQ-2120103813A/2021     21280
# 3               Alpha|hCoV-19/Canada/QC-1nIRE-U41918299Q/2021     13312
# 4                       Alpha|hCoV-19/Denmark/DCGC-93213/2021     23136
# ..                                                        ...       ...
# 414                          Zeta|hCoV-19/Brazil/SP-1007/2021     29872
# 415                  Zeta|hCoV-19/Brazil/SP-757331-NBD14/2021      8816
# 416                           Zeta|hCoV-19/Japan/IC-0493/2020     15120
# 417                 Zeta|hCoV-19/USA/CO-CDC-ASC210029043/2021      6064
# 418                   Zeta|hCoV-19/USA/WA-UW-21041469819/2021      2160
#
# Predicted_nu Target_nu    A    C    G    T
# 0                    A  4.0  6.0  1.0  5.0
# 1                    C  4.0  6.0  1.0  5.0
# 2                    T  4.0  6.0  1.0  5.0
# 3                    C  4.0  6.0  1.0  5.0
# 4                    T  4.0  6.0  1.0  5.0
# ..                 ...  ...  ...  ...  ...
# 414                  C  1.0  NaN  1.0  NaN
# 415                  T  4.0  6.0  1.0  5.0
# 416                  T  4.0  6.0  1.0  5.0
# 417                  G  4.0  6.0  1.0  5.0
# 418                  G  4.0  6.0  1.0  5.0
#
# [419 rows x 7 columns]

# %%
pivot_table['max'] = pivot_table[["A", "C", "T", "G"]].max(axis=1)
pivot_table['N'] = pivot_table[["A", "C", "T", "G"]].sum(axis=1)
pivot_table
# Out:
# Predicted_nu                                               id  Position  \
# 0             Alpha|hCoV-19/Belgium/Jessa_11-2119-002221/2021     21536
# 1             Alpha|hCoV-19/Bulgaria/21BG-EU_002140_Pl20/2021        16
# 2             Alpha|hCoV-19/Canada/QC-1nDJXQ-2120103813A/2021     21280
# 3               Alpha|hCoV-19/Canada/QC-1nIRE-U41918299Q/2021     13312
# 4                       Alpha|hCoV-19/Denmark/DCGC-93213/2021     23136
# ..                                                        ...       ...
# 414                          Zeta|hCoV-19/Brazil/SP-1007/2021     29872
# 415                  Zeta|hCoV-19/Brazil/SP-757331-NBD14/2021      8816
# 416                           Zeta|hCoV-19/Japan/IC-0493/2020     15120
# 417                 Zeta|hCoV-19/USA/CO-CDC-ASC210029043/2021      6064
# 418                   Zeta|hCoV-19/USA/WA-UW-21041469819/2021      2160
#
# Predicted_nu Target_nu    A    C    G    T  max     N
# 0                    A  4.0  6.0  1.0  5.0  6.0  16.0
# 1                    C  4.0  6.0  1.0  5.0  6.0  16.0
# 2                    T  4.0  6.0  1.0  5.0  6.0  16.0
# 3                    C  4.0  6.0  1.0  5.0  6.0  16.0
# 4                    T  4.0  6.0  1.0  5.0  6.0  16.0
# ..                 ...  ...  ...  ...  ...  ...   ...
# 414                  C  1.0  NaN  1.0  NaN  1.0   2.0
# 415                  T  4.0  6.0  1.0  5.0  6.0  16.0
# 416                  T  4.0  6.0  1.0  5.0  6.0  16.0
# 417                  G  4.0  6.0  1.0  5.0  6.0  16.0
# 418                  G  4.0  6.0  1.0  5.0  6.0  16.0
#
# [419 rows x 9 columns]

# %%
nu = ['A', 'C', 'T', 'G']
for n in nu:
    pivot_table[f'{n}_max'] = np.where(pivot_table[n] == pivot_table['max'], n, '')

# %%
# Apply the function to each row
pivot_table['E'] = pivot_table.apply(lambda row: [row['A_max'], row['C_max'], row['T_max'], row['G_max']], axis=1)
pivot_table['F'] = pivot_table['E'].apply(lambda row: [x for x in row if x != ''])
pivot_table['final'] = pivot_table['F'].apply(lambda row: np.random.choice(row))
pivot_table['correct'] = np.where(pivot_table['Target_nu'] == pivot_table['final'], 1,0)
pivot_table
# Out:
# Predicted_nu                                               id  Position  \
# 0             Alpha|hCoV-19/Belgium/Jessa_11-2119-002221/2021     21536
# 1             Alpha|hCoV-19/Bulgaria/21BG-EU_002140_Pl20/2021        16
# 2             Alpha|hCoV-19/Canada/QC-1nDJXQ-2120103813A/2021     21280
# 3               Alpha|hCoV-19/Canada/QC-1nIRE-U41918299Q/2021     13312
# 4                       Alpha|hCoV-19/Denmark/DCGC-93213/2021     23136
# ..                                                        ...       ...
# 414                          Zeta|hCoV-19/Brazil/SP-1007/2021     29872
# 415                  Zeta|hCoV-19/Brazil/SP-757331-NBD14/2021      8816
# 416                           Zeta|hCoV-19/Japan/IC-0493/2020     15120
# 417                 Zeta|hCoV-19/USA/CO-CDC-ASC210029043/2021      6064
# 418                   Zeta|hCoV-19/USA/WA-UW-21041469819/2021      2160
#
# Predicted_nu Target_nu    A    C    G    T  max     N A_max C_max T_max G_max  \
# 0                    A  4.0  6.0  1.0  5.0  6.0  16.0           C
# 1                    C  4.0  6.0  1.0  5.0  6.0  16.0           C
# 2                    T  4.0  6.0  1.0  5.0  6.0  16.0           C
# 3                    C  4.0  6.0  1.0  5.0  6.0  16.0           C
# 4                    T  4.0  6.0  1.0  5.0  6.0  16.0           C
# ..                 ...  ...  ...  ...  ...  ...   ...   ...   ...   ...   ...
# 414                  C  1.0  NaN  1.0  NaN  1.0   2.0     A                 G
# 415                  T  4.0  6.0  1.0  5.0  6.0  16.0           C
# 416                  T  4.0  6.0  1.0  5.0  6.0  16.0           C
# 417                  G  4.0  6.0  1.0  5.0  6.0  16.0           C
# 418                  G  4.0  6.0  1.0  5.0  6.0  16.0           C
#
# Predicted_nu           E       F final  correct
# 0              [, C, , ]     [C]     C        0
# 1              [, C, , ]     [C]     C        1
# 2              [, C, , ]     [C]     C        0
# 3              [, C, , ]     [C]     C        1
# 4              [, C, , ]     [C]     C        0
# ..                   ...     ...   ...      ...
# 414           [A, , , G]  [A, G]     G        0
# 415            [, C, , ]     [C]     C        0
# 416            [, C, , ]     [C]     C        0
# 417            [, C, , ]     [C]     C        0
# 418            [, C, , ]     [C]     C        0
#
# [419 rows x 17 columns]

# %%
pivot_table[['N','correct']].value_counts()
# Out:
# N     correct
# 16.0  0          314
#       1           97
# 2.0   0            3
# 9.0   0            2
# 1.0   0            1
# 3.0   1            1
# 5.0   0            1
# Name: count, dtype: int64

# %%
pivot_table.to_csv("COVID_RESULT", index=False)
